# %%
###########################################
# setting1  undersampled all              #
#                                         #
# setting 2 undersampled training         #
###########################################
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
import pandas as pd
import numpy as np
import statsmodels.api as sm
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from numpy import cov
from scipy import stats
import statsmodels.formula.api as smf
# Import train_test_split function
from sklearn.model_selection import train_test_split
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
from sklearn.metrics import roc_curve
# Split dataset into training set and test set
import sklearn
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.ensemble import BaggingClassifier

# %% [markdown]
# # 1. Setting 1: No resample, just normalize the data

# %%
##############################################
#   setting1 undersampled over all data     #
#############################################
x_train_setting1=np.loadtxt("preprocessed/x_train.csv", delimiter=",")
y_train_setting1=np.loadtxt("preprocessed/y_train.csv", delimiter=",")
x_valid_setting1=np.loadtxt("preprocessed/x_valid.csv", delimiter=",")
y_valid_setting1=np.loadtxt("preprocessed/y_valid.csv", delimiter=",")
x_test_setting1=np.loadtxt("preprocessed/x_test.csv", delimiter=",")
y_test_setting1=np.loadtxt("preprocessed/y_test.csv", delimiter=",")

# %%
#############################check training, validation, and testing data size

# %%
size_feature = x_train_setting1.shape[1]
size_train = x_train_setting1.shape[0]
size_valid = x_valid_setting1.shape[0]
size_test = x_test_setting1.shape[0]

print(f'feature size: {size_feature} | train size: {size_train} | validation size: {size_valid} | test size: {size_test}')
# Out:
# feature size: 44 | train size: 76538 | validation size: 9567 | test size: 9568

# %% [markdown]
# # 1.1 SVM Model parameter selection

# %%
#############################support vector machine

# %%
def train_validation(x_train, y_train,x_valid,y_valid, config):
    mean_loss_valid = 0.0

    print("train_validation function starts here.") 
    #Train the model using training data
#     clf = svm.SVC(C=config['reg_para'],kernel=config['kernel'])
    
    num_estimators = 10
    clf = BaggingClassifier(svm.SVC(C=config['reg_para'],kernel=config['kernel']), max_samples=1.0 / num_estimators, n_estimators=num_estimators, n_jobs=-1)
    clf.fit(x_train, y_train)
    
    #calculating the training accurary score
    yhat_train = clf.predict(x_train)
    acurracy_train=metrics.accuracy_score(y_train, yhat_train)
    #calculating the validation accurary score
    yhat_valid = clf.predict(x_valid)
    acurracy_valid=metrics.accuracy_score(y_valid, yhat_valid)
    
    
    print(f'\r[Info] config: {config} | training accuracy: {acurracy_train} | validation accuracy: {acurracy_valid}', end='')
    print('\n[Info] Done')
    return acurracy_train,acurracy_valid

# %%
config = dict(
    kernel = 'linear',
    reg_para = 1,

)

# %%
##There is no need to run this cell. Just for debugging purpose.

acurracy_train,acurracy_valid=train_validation(x_train_setting1, y_train_setting1,x_valid_setting1,y_valid_setting1, config)
# Out:
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8876345771924323
# [Info] Done

# %% [markdown]
# ### 1.1.1 Impact of Different kernel functions and regularization parameters under setting 1

# %%
##Run the model using different kernels and reg_para's setting
#use mean_loss_valid as metric to design which setting is best
#
kernel_list=['linear', 'poly', 'rbf', 'sigmoid']
reg_para_list=[0.6,0.8,1.0,1.2,1.4]
acurracy_train_matrix=np.zeros((len(kernel_list),len(reg_para_list)))
acurracy_valid_matrix=np.zeros((len(kernel_list),len(reg_para_list)))

for i,k in enumerate(kernel_list):
    for j,a in enumerate(reg_para_list):
        #print(config)
        config['kernel']=k
        config['reg_para']=a
        acurracy_train_matrix[i][j],acurracy_valid_matrix[i][j]=train_validation(x_train_setting1, y_train_setting1,x_valid_setting1,y_valid_setting1, config)
# Out:
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 0.6} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 0.8} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1.0} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1.2} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1.4} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.6} | training accuracy: 0.8855209177140767 | validation accuracy: 0.8874255252430229
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.8} | training accuracy: 0.8851420209569103 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 1.0} | training accuracy: 0.8851942825785885 | validation accuracy: 0.8870074213442041
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 1.2} | training accuracy: 0.8854425252815595 | validation accuracy: 0.8870074213442041
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 1.4} | training accuracy: 0.8852857404165251 | validation accuracy: 0.887739103167137
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 0.6} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 0.8} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8875300512177277
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 1.0} | training accuracy: 0.8848676474431002 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 1.2} | training accuracy: 0.8848937782539392 | validation accuracy: 0.8875300512177277
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 1.4} | training accuracy: 0.8849591052810368 | validation accuracy: 0.8876345771924323
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 0.6} | training accuracy: 0.8684836290470094 | validation accuracy: 0.8726873628096582
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 0.8} | training accuracy: 0.8708615328333639 | validation accuracy: 0.8741507264555242
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 1.0} | training accuracy: 0.8586976403877812 | validation accuracy: 0.8616076094909585
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 1.2} | training accuracy: 0.8578745198463509 | validation accuracy: 0.8601442458450925
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 1.4} | training accuracy: 0.8506754814601897 | validation accuracy: 0.8572175185533605
# [Info] Done

# %% [markdown]
# ### 1.1.2 Plot the heatmap of validation accuracy

# %%
figure = plt.figure()
axes = figure.add_subplot(111)
 
# using the matshow() function
caxes = axes.matshow(acurracy_valid_matrix, interpolation ='nearest')
figure.colorbar(caxes)
 
axes.set_xticklabels(['']+reg_para_list)
axes.set_yticklabels(['']+kernel_list)
axes.set_xlabel("reg_para_list")
axes.set_ylabel("kernel_list")
 
plt.show()

# %% [markdown]
# From the heatmap above, we know valiadation accuracy is **highest (0.8876345771924323)** under the **'linear' kernel** with all regularization parameters from 0.6 to 1.4 and under **'rbf' kernel** from 0.6 to 1.2.

# %% [markdown]
# ## 1.2 Train the model using the best set of parameters

# %%
def test_validation(x_train, y_train,x_test,y_test, config):
    

    print("test_validation function starts here.") 
    #Train the model using training data
    num_estimators = 10
    clf = BaggingClassifier(svm.SVC(C=config['reg_para'],kernel=config['kernel']), max_samples=1.0 / num_estimators, n_estimators=num_estimators, n_jobs=-1)
    clf.fit(x_train, y_train)
    
    #calculating the training accurary score
    yhat_train = clf.predict(x_train)
    acurracy_train=metrics.accuracy_score(y_train, yhat_train)
    #calculating the validation accurary score
    yhat_test = clf.predict(x_test)
    acurracy_test=metrics.accuracy_score(y_test, yhat_test)
    

    
    print(f'\r[Info] config: {config} | training accuracy: {acurracy_train} | testing accuracy: {acurracy_test}', end='')
    #Print out the classification report
    print("\n","classification report:",metrics.classification_report(y_test, yhat_test))
    print("confusion matrix:",confusion_matrix(y_test, yhat_test))
    roc_auc=roc_auc_score(y_test,yhat_test,average=None)
    print("ROC_AUC_score",roc_auc)
    print('\n[Info] Done')

    ####Plot the heatmap
    plt.figure(figsize=(9,9))
    sns.heatmap(confusion_matrix(y_test, yhat_test), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Reds_r');
    plt.ylabel('Actual label');
    plt.xlabel('Predicted label');
    all_sample_title = 'Accuracy Score: {0}'.format(acurracy_test)
    plt.title(all_sample_title, size = 15)
    
    
    return yhat_test,acurracy_test,roc_auc

# %%
#Best configuration based on the result above
best_config = dict(
    kernel = 'linear',
    reg_para = 1.0,

)

# %%
#Train the support vector machine model using the best_config
#yhat_test,acurracy_test,roc_auc=test_validation(x_train_setting1, y_train_setting1,x_test_setting1,y_test_setting1, best_config)

# %%
#####################################################################################################
#Run 5 times and calculate the avg testing acurracy (acurracy_test) and avg roc_auc score (roc_auc)
####################################################################################################
acurracy_test_list=np.zeros(5)
roc_auc_list=np.zeros(5)
for i in range(0,5):
    yhat_test,acurracy_test_list[i],roc_auc_list[i]=test_validation(x_train_setting1, y_train_setting1,x_test_setting1,y_test_setting1, best_config)
    print(f'\n[Info] number of iter: {i} | testing accuracy: {acurracy_test_list[i]} | roc_auc score: {roc_auc_list[i]}', end='')



print("mean of testing accuracy",np.mean(acurracy_test_list),"mean of roc_auc score",np.mean(roc_auc_list))
# Out:
# test_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1.0} | training accuracy: 0.8848676474431002 | testing accuracy: 0.8812709030100334
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.88      1.00      0.94      8432
#          1.0       0.00      0.00      0.00      1136
#
#     accuracy                           0.88      9568
#    macro avg       0.44      0.50      0.47      9568
# weighted avg       0.78      0.88      0.83      9568
#
# confusion matrix: [[8432    0]
#  [1136    0]]
# ROC_AUC_score 0.5
#
# [Info] Done
#
# [Info] number of iter: 0 | testing accuracy: 0.8812709030100334 | roc_auc score: 0.5
# C:\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1.0} | training accuracy: 0.8848676474431002 | testing accuracy: 0.8812709030100334
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.88      1.00      0.94      8432
#          1.0       0.00      0.00      0.00      1136
#
#     accuracy                           0.88      9568
#    macro avg       0.44      0.50      0.47      9568
# weighted avg       0.78      0.88      0.83      9568
#
# confusion matrix: [[8432    0]
#  [1136    0]]
# ROC_AUC_score 0.5
#
# [Info] Done
#
# [Info] number of iter: 1 | testing accuracy: 0.8812709030100334 | roc_auc score: 0.5test_validation function starts here.
# C:\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Info] config: {'kernel': 'linear', 'reg_para': 1.0} | training accuracy: 0.8848676474431002 | testing accuracy: 0.8812709030100334
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.88      1.00      0.94      8432
#          1.0       0.00      0.00      0.00      1136
#
#     accuracy                           0.88      9568
#    macro avg       0.44      0.50      0.47      9568
# weighted avg       0.78      0.88      0.83      9568
#
# confusion matrix: [[8432    0]
#  [1136    0]]
# ROC_AUC_score 0.5
#
# [Info] Done
#
# [Info] number of iter: 2 | testing accuracy: 0.8812709030100334 | roc_auc score: 0.5test_validation function starts here.
# C:\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Info] config: {'kernel': 'linear', 'reg_para': 1.0} | training accuracy: 0.8848676474431002 | testing accuracy: 0.8812709030100334
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.88      1.00      0.94      8432
#          1.0       0.00      0.00      0.00      1136
#
#     accuracy                           0.88      9568
#    macro avg       0.44      0.50      0.47      9568
# weighted avg       0.78      0.88      0.83      9568
#
# confusion matrix: [[8432    0]
#  [1136    0]]
# ROC_AUC_score 0.5
#
# [Info] Done
#
# [Info] number of iter: 3 | testing accuracy: 0.8812709030100334 | roc_auc score: 0.5test_validation function starts here.
# C:\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Info] config: {'kernel': 'linear', 'reg_para': 1.0} | training accuracy: 0.8848676474431002 | testing accuracy: 0.8812709030100334
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.88      1.00      0.94      8432
#          1.0       0.00      0.00      0.00      1136
#
#     accuracy                           0.88      9568
#    macro avg       0.44      0.50      0.47      9568
# weighted avg       0.78      0.88      0.83      9568
#
# confusion matrix: [[8432    0]
#  [1136    0]]
# ROC_AUC_score 0.5
#
# [Info] Done
#
# [Info] number of iter: 4 | testing accuracy: 0.8812709030100334 | roc_auc score: 0.5mean of testing accuracy 0.8812709030100334 mean of roc_auc score 0.5
# C:\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
##############
# ROC Curve #
#############
fpr, tpr, thresholds=roc_curve(y_test_setting1, yhat_test)
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label='SVM Classifier')
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='random', alpha=.8)
plt.xlim([0,1])
plt.ylim([0,1])
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()
plt.axes().set_aspect('equal')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# <ipython-input-15-ae9a3815c563>:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_aspect('equal')
# Text(0, 0.5, 'True Positive Rate')

# %% [markdown]
# # 2. Setting 2: undersampled over training data

# %%
###########################################################
#    undersampled setting 2, undersample training only    #
###########################################################
x_train_undersampled = np.loadtxt("preprocessed/x_train_resampled.csv", delimiter=',')
y_train_undersampled = np.loadtxt("preprocessed/y_train_resampled.csv", delimiter=',')
x_valid=np.loadtxt("preprocessed/x_valid.csv",delimiter=",")
y_valid=np.loadtxt("preprocessed/y_valid.csv",delimiter=",")
x_test=np.loadtxt("preprocessed/x_test.csv",delimiter=",")
y_test=np.loadtxt("preprocessed/y_test.csv",delimiter=",")

# %%
size_feature = x_train_undersampled.shape[1]
size_train = x_train_undersampled.shape[0]
size_valid = x_valid.shape[0]
size_test = x_test.shape[0]

print(f'feature size: {size_feature} | train size: {size_train} | validation size: {size_valid} | test size: {size_test}')
# Out:
# feature size: 44 | train size: 17624 | validation size: 9567 | test size: 9568

# %% [markdown]
# ### 2.1 Parameter selection

# %%
##Run the model using different kernels and reg_para's setting
#use mean_loss_valid as metric to design which setting is best
#
kernel_list=['linear', 'poly', 'rbf', 'sigmoid']
reg_para_list=[0.6,0.8,1.0,1.2,1.4]
acurracy_train_matrix_2=np.zeros((len(kernel_list),len(reg_para_list)))
acurracy_valid_matrix_2=np.zeros((len(kernel_list),len(reg_para_list)))

for i,k in enumerate(kernel_list):
    for j,a in enumerate(reg_para_list):
        #print(config)
        config['kernel']=k
        config['reg_para']=a
        #print(config)
        acurracy_train_matrix_2[i][j],acurracy_valid_matrix_2[i][j]=train_validation(x_train_undersampled, y_train_undersampled,x_valid,y_valid, config)
# Out:
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 0.6} | training accuracy: 0.5978211529732184 | validation accuracy: 0.7112992578655796
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 0.8} | training accuracy: 0.5931116659101225 | validation accuracy: 0.7220654332601651
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1.0} | training accuracy: 0.594984112573763 | validation accuracy: 0.7062820110797533
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1.2} | training accuracy: 0.5963458919655016 | validation accuracy: 0.720288491690185
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'linear', 'reg_para': 1.4} | training accuracy: 0.5957217430776214 | validation accuracy: 0.712971673460855
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.6} | training accuracy: 0.568656377666818 | validation accuracy: 0.8226194209261002
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.8} | training accuracy: 0.580458465728552 | validation accuracy: 0.8075676805686213
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 1.0} | training accuracy: 0.5887426236949614 | validation accuracy: 0.7839448102853559
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 1.2} | training accuracy: 0.5939627780299591 | validation accuracy: 0.7785094596007108
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 1.4} | training accuracy: 0.5960621879255561 | validation accuracy: 0.7802864011706909
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 0.6} | training accuracy: 0.6083749432591921 | validation accuracy: 0.700533082470994
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 0.8} | training accuracy: 0.6107580571947344 | validation accuracy: 0.6703250757813317
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 1.0} | training accuracy: 0.616942805265547 | validation accuracy: 0.6772237901118427
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 1.2} | training accuracy: 0.6192124375851112 | validation accuracy: 0.6801505174035748
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'rbf', 'reg_para': 1.4} | training accuracy: 0.6201202905129369 | validation accuracy: 0.6867356538099718
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 0.6} | training accuracy: 0.5900476622787109 | validation accuracy: 0.7075363227762099
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 0.8} | training accuracy: 0.5843735814798002 | validation accuracy: 0.6824500888470785
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 1.0} | training accuracy: 0.5834657285519745 | validation accuracy: 0.6751332706177485
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 1.2} | training accuracy: 0.5805719473445302 | validation accuracy: 0.6575729068673566
# [Info] Done
# train_validation function starts here.
# [Info] config: {'kernel': 'sigmoid', 'reg_para': 1.4} | training accuracy: 0.5817635043123014 | validation accuracy: 0.6727291731995401
# [Info] Done

# %% [markdown]
# ### Plot the heatmap of validation accuracy

# %%
figure = plt.figure()
axes = figure.add_subplot(111)
 
# using the matshow() function
caxes = axes.matshow(acurracy_valid_matrix_2, interpolation ='nearest')
figure.colorbar(caxes)
 
axes.set_xticklabels(['']+reg_para_list)
axes.set_yticklabels(['']+kernel_list)
axes.set_xlabel("reg_para_list")
axes.set_ylabel("kernel_list")
 
plt.show()

# %% [markdown]
# From the heatmap above, we know valiadation accuracy is **highest (0.8226194209261002)** under the **'polynomial' kernel** and the regularization parameters is 0.6

# %%
#Best configuration based on the result above
#We just use reg_para =1.0
best_config_2 = dict(
    kernel = 'poly',
    reg_para = 0.6,

)

# %%
acurracy_test_list=np.zeros(5)
roc_auc_list=np.zeros(5)
for i in range(0,5):
    yhat_test_2,acurracy_test_list[i],roc_auc_list[i]=test_validation(x_train_undersampled, y_train_undersampled,x_test,y_test, best_config_2)
    print(f'\n[Info] number of iter: {i} | testing accuracy: {acurracy_test_list[i]} | roc_auc score: {roc_auc_list[i]}', end='')


    

print("mean of testing accuracy",np.mean(acurracy_test_list),"mean of roc_auc score",np.mean(roc_auc_list))
# Out:
# test_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.6} | training accuracy: 0.5578188833408988 | testing accuracy: 0.8351797658862876
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.89      0.92      0.91      8432
#          1.0       0.24      0.18      0.20      1136
#
#     accuracy                           0.84      9568
#    macro avg       0.56      0.55      0.55      9568
# weighted avg       0.81      0.84      0.82      9568
#
# confusion matrix: [[7792  640]
#  [ 937  199]]
# ROC_AUC_score 0.5496373640323917
#
# [Info] Done
#
# [Info] number of iter: 0 | testing accuracy: 0.8351797658862876 | roc_auc score: 0.5496373640323917test_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.6} | training accuracy: 0.5746709033136632 | testing accuracy: 0.8173076923076923
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90      8432
#          1.0       0.23      0.24      0.23      1136
#
#     accuracy                           0.82      9568
#    macro avg       0.57      0.57      0.57      9568
# weighted avg       0.82      0.82      0.82      9568
#
# confusion matrix: [[7552  880]
#  [ 868  268]]
# ROC_AUC_score 0.5657755832910175
#
# [Info] Done
#
# [Info] number of iter: 1 | testing accuracy: 0.8173076923076923 | roc_auc score: 0.5657755832910175test_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.6} | training accuracy: 0.572401270994099 | testing accuracy: 0.8152173913043478
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.90      0.89      0.90      8432
#          1.0       0.22      0.23      0.23      1136
#
#     accuracy                           0.82      9568
#    macro avg       0.56      0.56      0.56      9568
# weighted avg       0.82      0.82      0.82      9568
#
# confusion matrix: [[7542  890]
#  [ 878  258]]
# ROC_AUC_score 0.5607811957131784
#
# [Info] Done
#
# [Info] number of iter: 2 | testing accuracy: 0.8152173913043478 | roc_auc score: 0.5607811957131784test_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.6} | training accuracy: 0.564400817067635 | testing accuracy: 0.8212792642140468
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90      8432
#          1.0       0.24      0.23      0.23      1136
#
#     accuracy                           0.82      9568
#    macro avg       0.57      0.56      0.57      9568
# weighted avg       0.82      0.82      0.82      9568
#
# confusion matrix: [[7600  832]
#  [ 878  258]]
# ROC_AUC_score 0.5642204746505599
#
# [Info] Done
#
# [Info] number of iter: 3 | testing accuracy: 0.8212792642140468 | roc_auc score: 0.5642204746505599test_validation function starts here.
# [Info] config: {'kernel': 'poly', 'reg_para': 0.6} | training accuracy: 0.5673513390830686 | testing accuracy: 0.8228469899665551
#  classification report:               precision    recall  f1-score   support
#
#          0.0       0.89      0.91      0.90      8432
#          1.0       0.23      0.21      0.22      1136
#
#     accuracy                           0.82      9568
#    macro avg       0.56      0.56      0.56      9568
# weighted avg       0.82      0.82      0.82      9568
#
# confusion matrix: [[7634  798]
#  [ 897  239]]
# ROC_AUC_score 0.5578739276264799
#
# [Info] Done
#
# [Info] number of iter: 4 | testing accuracy: 0.8228469899665551 | roc_auc score: 0.5578739276264799mean of testing accuracy 0.8223662207357858 mean of roc_auc score 0.5596577090627255

# %%
#Train the support vector machine model using the best_config
#yhat_train_2, yhat_test_2=test_validation(x_train_undersampled, y_train_undersampled,x_test,y_test, best_config_2)

# %%
##############
# ROC Curve #
#############
fpr, tpr, thresholds=roc_curve(y_test, yhat_test_2)
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label='SVM Classifier')
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='random', alpha=.8)
plt.xlim([0,1])
plt.ylim([0,1])
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()
plt.axes().set_aspect('equal')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# <ipython-input-27-c5d10520d5d6>:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_aspect('equal')
# Text(0, 0.5, 'True Positive Rate')
