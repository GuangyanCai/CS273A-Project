# %%
#######################
# preprocessing data #  row90
#####################

# %%
cd C:/Users/peng1/OneDrive/Desktop/cs273A
# Out:
# C:\Users\peng1\OneDrive\Desktop\cs273A

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from numpy import cov
from scipy import stats
import statsmodels.formula.api as smf

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('diabetic_data.csv', index_col=0, parse_dates=True)
df.head()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)      ?
# 149190           55629189        Caucasian  Female  [10-20)      ?
# 64410            86047875  AfricanAmerican  Female  [20-30)      ?
# 500364           82442376        Caucasian    Male  [30-40)      ?
# 16680            42519267        Caucasian    Male  [40-50)      ?
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code  \
# encounter_id
# 2278392                         1                 1          ?
# 149190                          7                 3          ?
# 64410                           7                 2          ?
# 500364                          7                 2          ?
# 16680                           7                 1          ?
#
#                      medical_specialty  num_lab_procedures  num_procedures  \
# encounter_id
# 2278392       Pediatrics-Endocrinology                  41               0
# 149190                               ?                  59               0
# 64410                                ?                  11               5
# 500364                               ?                  44               1
# 16680                                ?                  51               0
#
#               num_medications  number_outpatient  number_emergency  \
# encounter_id
# 2278392                     1                  0                 0
# 149190                     18                  0                 0
# 64410                      13                  2                 0
# 500364                     16                  0                 0
# 16680                       8                  0                 0
#
#               number_inpatient  diag_1  diag_2 diag_3  number_diagnoses  \
# encounter_id
# 2278392                      0  250.83       ?      ?                 1
# 149190                       0     276  250.01    255                 9
# 64410                        1     648     250    V27                 6
# 500364                       0       8  250.43    403                 7
# 16680                        0     197     157    250                 5
#
#              max_glu_serum A1Cresult metformin repaglinide nateglinide  \
# encounter_id
# 2278392               None      None        No          No          No
# 149190                None      None        No          No          No
# 64410                 None      None        No          No          No
# 500364                None      None        No          No          No
# 16680                 None      None        No          No          No
#
#              chlorpropamide glimepiride acetohexamide glipizide glyburide  \
# encounter_id
# 2278392                  No          No            No        No        No
# 149190                   No          No            No        No        No
# 64410                    No          No            No    Steady        No
# 500364                   No          No            No        No        No
# 16680                    No          No            No    Steady        No
#
#              tolbutamide pioglitazone rosiglitazone acarbose miglitol  \
# encounter_id
# 2278392               No           No            No       No       No
# 149190                No           No            No       No       No
# 64410                 No           No            No       No       No
# 500364                No           No            No       No       No
# 16680                 No           No            No       No       No
#
#              troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 2278392                No         No      No          No      No
# 149190                 No         No      No          No      Up
# 64410                  No         No      No          No      No
# 500364                 No         No      No          No      Up
# 16680                  No         No      No          No  Steady
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 2278392                       No                  No                       No
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 2278392                           No                     No     No
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
#
#              diabetesMed readmitted
# encounter_id
# 2278392               No         NO
# 149190               Yes        >30
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO

# %%
missing_values = ["n/a", "na", "--","?"]
df1= pd.read_csv("diabetic_data.csv",index_col=0, parse_dates=True,na_values = missing_values)
df1["readmitted"].replace({">30": "NO"}, inplace=True)
print(df1)
#df1["diag_1"]=df1["diag_1"].str.replace("250","YES")
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)    NaN
# 149190           55629189        Caucasian  Female  [10-20)    NaN
# 64410            86047875  AfricanAmerican  Female  [20-30)    NaN
# 500364           82442376        Caucasian    Male  [30-40)    NaN
# 16680            42519267        Caucasian    Male  [40-50)    NaN
# ...                   ...              ...     ...      ...    ...
# 443847548       100162476  AfricanAmerican    Male  [70-80)    NaN
# 443847782        74694222  AfricanAmerican  Female  [80-90)    NaN
# 443854148        41088789        Caucasian    Male  [70-80)    NaN
# 443857166        31693671        Caucasian  Female  [80-90)    NaN
# 443867222       175429310        Caucasian    Male  [70-80)    NaN
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
# ...                         ...                       ...
# 443847548                     1                         3
# 443847782                     1                         4
# 443854148                     1                         1
# 443857166                     2                         3
# 443867222                     1                         1
#
#               admission_source_id  time_in_hospital payer_code  \
# encounter_id
# 2278392                         1                 1        NaN
# 149190                          7                 3        NaN
# 64410                           7                 2        NaN
# 500364                          7                 2        NaN
# 16680                           7                 1        NaN
# ...                           ...               ...        ...
# 443847548                       7                 3         MC
# 443847782                       5                 5         MC
# 443854148                       7                 1         MC
# 443857166                       7                10         MC
# 443867222                       7                 6        NaN
#
#                      medical_specialty  num_lab_procedures  num_procedures  \
# encounter_id
# 2278392       Pediatrics-Endocrinology                  41               0
# 149190                             NaN                  59               0
# 64410                              NaN                  11               5
# 500364                             NaN                  44               1
# 16680                              NaN                  51               0
# ...                                ...                 ...             ...
# 443847548                          NaN                  51               0
# 443847782                          NaN                  33               3
# 443854148                          NaN                  53               0
# 443857166              Surgery-General                  45               2
# 443867222                          NaN                  13               3
#
#               num_medications  number_outpatient  number_emergency  \
# encounter_id
# 2278392                     1                  0                 0
# 149190                     18                  0                 0
# 64410                      13                  2                 0
# 500364                     16                  0                 0
# 16680                       8                  0                 0
# ...                       ...                ...               ...
# 443847548                  16                  0                 0
# 443847782                  18                  0                 0
# 443854148                   9                  1                 0
# 443857166                  21                  0                 0
# 443867222                   3                  0                 0
#
#               number_inpatient  diag_1  diag_2 diag_3  number_diagnoses  \
# encounter_id
# 2278392                      0  250.83     NaN    NaN                 1
# 149190                       0     276  250.01    255                 9
# 64410                        1     648     250    V27                 6
# 500364                       0       8  250.43    403                 7
# 16680                        0     197     157    250                 5
# ...                        ...     ...     ...    ...               ...
# 443847548                    0  250.13     291    458                 9
# 443847782                    1     560     276    787                 9
# 443854148                    0      38     590    296                13
# 443857166                    1     996     285    998                 9
# 443867222                    0     530     530    787                 9
#
#              max_glu_serum A1Cresult metformin repaglinide nateglinide  \
# encounter_id
# 2278392               None      None        No          No          No
# 149190                None      None        No          No          No
# 64410                 None      None        No          No          No
# 500364                None      None        No          No          No
# 16680                 None      None        No          No          No
# ...                    ...       ...       ...         ...         ...
# 443847548             None        >8    Steady          No          No
# 443847782             None      None        No          No          No
# 443854148             None      None    Steady          No          No
# 443857166             None      None        No          No          No
# 443867222             None      None        No          No          No
#
#              chlorpropamide glimepiride acetohexamide glipizide glyburide  \
# encounter_id
# 2278392                  No          No            No        No        No
# 149190                   No          No            No        No        No
# 64410                    No          No            No    Steady        No
# 500364                   No          No            No        No        No
# 16680                    No          No            No    Steady        No
# ...                     ...         ...           ...       ...       ...
# 443847548                No          No            No        No        No
# 443847782                No          No            No        No        No
# 443854148                No          No            No        No        No
# 443857166                No          No            No    Steady        No
# 443867222                No          No            No        No        No
#
#              tolbutamide pioglitazone rosiglitazone acarbose miglitol  \
# encounter_id
# 2278392               No           No            No       No       No
# 149190                No           No            No       No       No
# 64410                 No           No            No       No       No
# 500364                No           No            No       No       No
# 16680                 No           No            No       No       No
# ...                  ...          ...           ...      ...      ...
# 443847548             No           No            No       No       No
# 443847782             No           No            No       No       No
# 443854148             No           No            No       No       No
# 443857166             No       Steady            No       No       No
# 443867222             No           No            No       No       No
#
#              troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 2278392                No         No      No          No      No
# 149190                 No         No      No          No      Up
# 64410                  No         No      No          No      No
# 500364                 No         No      No          No      Up
# 16680                  No         No      No          No  Steady
# ...                   ...        ...     ...         ...     ...
# 443847548              No         No      No          No    Down
# 443847782              No         No      No          No  Steady
# 443854148              No         No      No          No    Down
# 443857166              No         No      No          No      Up
# 443867222              No         No      No          No      No
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 2278392                       No                  No                       No
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
# ...                          ...                 ...                      ...
# 443847548                     No                  No                       No
# 443847782                     No                  No                       No
# 443854148                     No                  No                       No
# 443857166                     No                  No                       No
# 443867222                     No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 2278392                           No                     No     No
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
# ...                              ...                    ...    ...
# 443847548                         No                     No     Ch
# 443847782                         No                     No     No
# 443854148                         No                     No     Ch
# 443857166                         No                     No     Ch
# 443867222                         No                     No     No
#
#              diabetesMed readmitted
# encounter_id
# 2278392               No         NO
# 149190               Yes         NO
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO
# ...                  ...        ...
# 443847548            Yes         NO
# 443847782            Yes         NO
# 443854148            Yes         NO
# 443857166            Yes         NO
# 443867222             No         NO
#
# [101766 rows x 49 columns]
# D:\anacod\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1 = df1[((df1.discharge_disposition_id != 11) & 
                                          (df1.discharge_disposition_id != 13) &
                                          (df1.discharge_disposition_id != 14) & 
                                          (df1.discharge_disposition_id != 19) & 
                                          (df1.discharge_disposition_id != 20) & 
                                          (df1.discharge_disposition_id != 21))]

# %%
icd9code = [(1, 139),
            (140, 239),
            (240, 279),
            (280, 289),
            (290, 319),
            (320, 389),
            (390, 459),
            (460, 519),
            (520, 579),
            (580, 629),
            (630, 679),
            (680, 709),
            (710, 739),
            (740, 759),
            (760, 779),
            (780, 799),
            (800, 999)]
icd9codelist = ['Infectious And Parasitic Diseases',
                'Neoplasms',
                'Endocrine, Nutritional And Metabolic Diseases, And Immunity Disorders',
                'Diseases Of The Blood And Blood-Forming Organs',
                'Mental Disorders',
                'Diseases Of The Nervous System And Sense Organs',
                'Diseases Of The Circulatory System',
                'Diseases Of The Respiratory System',
                'Diseases Of The Digestive System',
                'Diseases Of The Genitourinary System',
                'Complications Of Pregnancy, Childbirth, And The Puerperium',
                'Diseases Of The Skin And Subcutaneous Tissue',
                'Diseases Of The Musculoskeletal System And Connective Tissue',
                'Congential Anomalies',
                'Certain Conditions Originating In The Perinatal Period',
                'Symptoms, Signs, And Ill-Defined Conditions',
                'Injury And Poisoning']

# %%
codes = zip(icd9code, icd9codelist)
codelist = set(codes)
codelist
# Out:
# {((1, 139), 'Infectious And Parasitic Diseases'),
#  ((140, 239), 'Neoplasms'),
#  ((240, 279),
#   'Endocrine, Nutritional And Metabolic Diseases, And Immunity Disorders'),
#  ((280, 289), 'Diseases Of The Blood And Blood-Forming Organs'),
#  ((290, 319), 'Mental Disorders'),
#  ((320, 389), 'Diseases Of The Nervous System And Sense Organs'),
#  ((390, 459), 'Diseases Of The Circulatory System'),
#  ((460, 519), 'Diseases Of The Respiratory System'),
#  ((520, 579), 'Diseases Of The Digestive System'),
#  ((580, 629), 'Diseases Of The Genitourinary System'),
#  ((630, 679), 'Complications Of Pregnancy, Childbirth, And The Puerperium'),
#  ((680, 709), 'Diseases Of The Skin And Subcutaneous Tissue'),
#  ((710, 739), 'Diseases Of The Musculoskeletal System And Connective Tissue'),
#  ((740, 759), 'Congential Anomalies'),
#  ((760, 779), 'Certain Conditions Originating In The Perinatal Period'),
#  ((780, 799), 'Symptoms, Signs, And Ill-Defined Conditions'),
#  ((800, 999), 'Injury And Poisoning')}

# %%
for num_range, diagnosis in codelist:
    oldlist = range(num_range[0], num_range[1]+1)
    oldlist = [str(x) for x in oldlist]
    newlist = [diagnosis] * len(oldlist)
    for col in ['diag_1', 'diag_2', 'diag_3']:
        df1[col].replace(oldlist, newlist, inplace=True)
df1
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)    NaN
# 149190           55629189        Caucasian  Female  [10-20)    NaN
# 64410            86047875  AfricanAmerican  Female  [20-30)    NaN
# 500364           82442376        Caucasian    Male  [30-40)    NaN
# 16680            42519267        Caucasian    Male  [40-50)    NaN
# ...                   ...              ...     ...      ...    ...
# 443847548       100162476  AfricanAmerican    Male  [70-80)    NaN
# 443847782        74694222  AfricanAmerican  Female  [80-90)    NaN
# 443854148        41088789        Caucasian    Male  [70-80)    NaN
# 443857166        31693671        Caucasian  Female  [80-90)    NaN
# 443867222       175429310        Caucasian    Male  [70-80)    NaN
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
# ...                         ...                       ...
# 443847548                     1                         3
# 443847782                     1                         4
# 443854148                     1                         1
# 443857166                     2                         3
# 443867222                     1                         1
#
#               admission_source_id  time_in_hospital payer_code  \
# encounter_id
# 2278392                         1                 1        NaN
# 149190                          7                 3        NaN
# 64410                           7                 2        NaN
# 500364                          7                 2        NaN
# 16680                           7                 1        NaN
# ...                           ...               ...        ...
# 443847548                       7                 3         MC
# 443847782                       5                 5         MC
# 443854148                       7                 1         MC
# 443857166                       7                10         MC
# 443867222                       7                 6        NaN
#
#                      medical_specialty  num_lab_procedures  num_procedures  \
# encounter_id
# 2278392       Pediatrics-Endocrinology                  41               0
# 149190                             NaN                  59               0
# 64410                              NaN                  11               5
# 500364                             NaN                  44               1
# 16680                              NaN                  51               0
# ...                                ...                 ...             ...
# 443847548                          NaN                  51               0
# 443847782                          NaN                  33               3
# 443854148                          NaN                  53               0
# 443857166              Surgery-General                  45               2
# 443867222                          NaN                  13               3
#
#               num_medications  number_outpatient  number_emergency  \
# encounter_id
# 2278392                     1                  0                 0
# 149190                     18                  0                 0
# 64410                      13                  2                 0
# 500364                     16                  0                 0
# 16680                       8                  0                 0
# ...                       ...                ...               ...
# 443847548                  16                  0                 0
# 443847782                  18                  0                 0
# 443854148                   9                  1                 0
# 443857166                  21                  0                 0
# 443867222                   3                  0                 0
#
#               number_inpatient  \
# encounter_id
# 2278392                      0
# 149190                       0
# 64410                        1
# 500364                       0
# 16680                        0
# ...                        ...
# 443847548                    0
# 443847782                    1
# 443854148                    0
# 443857166                    1
# 443867222                    0
#
#                                                          diag_1  \
# encounter_id
# 2278392                                                  250.83
# 149190        Endocrine, Nutritional And Metabolic Diseases,...
# 64410         Complications Of Pregnancy, Childbirth, And Th...
# 500364                        Infectious And Parasitic Diseases
# 16680                                                 Neoplasms
# ...                                                         ...
# 443847548                                                250.13
# 443847782                      Diseases Of The Digestive System
# 443854148                     Infectious And Parasitic Diseases
# 443857166                                  Injury And Poisoning
# 443867222                      Diseases Of The Digestive System
#
#                                                          diag_2  \
# encounter_id
# 2278392                                                     NaN
# 149190                                                   250.01
# 64410         Endocrine, Nutritional And Metabolic Diseases,...
# 500364                                                   250.43
# 16680                                                 Neoplasms
# ...                                                         ...
# 443847548                                      Mental Disorders
# 443847782     Endocrine, Nutritional And Metabolic Diseases,...
# 443854148                  Diseases Of The Genitourinary System
# 443857166        Diseases Of The Blood And Blood-Forming Organs
# 443867222                      Diseases Of The Digestive System
#
#                                                          diag_3  \
# encounter_id
# 2278392                                                     NaN
# 149190        Endocrine, Nutritional And Metabolic Diseases,...
# 64410                                                       V27
# 500364                       Diseases Of The Circulatory System
# 16680         Endocrine, Nutritional And Metabolic Diseases,...
# ...                                                         ...
# 443847548                    Diseases Of The Circulatory System
# 443847782           Symptoms, Signs, And Ill-Defined Conditions
# 443854148                                      Mental Disorders
# 443857166                                  Injury And Poisoning
# 443867222           Symptoms, Signs, And Ill-Defined Conditions
#
#               number_diagnoses max_glu_serum A1Cresult metformin repaglinide  \
# encounter_id
# 2278392                      1          None      None        No          No
# 149190                       9          None      None        No          No
# 64410                        6          None      None        No          No
# 500364                       7          None      None        No          No
# 16680                        5          None      None        No          No
# ...                        ...           ...       ...       ...         ...
# 443847548                    9          None        >8    Steady          No
# 443847782                    9          None      None        No          No
# 443854148                   13          None      None    Steady          No
# 443857166                    9          None      None        No          No
# 443867222                    9          None      None        No          No
#
#              nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# encounter_id
# 2278392               No             No          No            No        No
# 149190                No             No          No            No        No
# 64410                 No             No          No            No    Steady
# 500364                No             No          No            No        No
# 16680                 No             No          No            No    Steady
# ...                  ...            ...         ...           ...       ...
# 443847548             No             No          No            No        No
# 443847782             No             No          No            No        No
# 443854148             No             No          No            No        No
# 443857166             No             No          No            No    Steady
# 443867222             No             No          No            No        No
#
#              glyburide tolbutamide pioglitazone rosiglitazone acarbose  \
# encounter_id
# 2278392             No          No           No            No       No
# 149190              No          No           No            No       No
# 64410               No          No           No            No       No
# 500364              No          No           No            No       No
# 16680               No          No           No            No       No
# ...                ...         ...          ...           ...      ...
# 443847548           No          No           No            No       No
# 443847782           No          No           No            No       No
# 443854148           No          No           No            No       No
# 443857166           No          No       Steady            No       No
# 443867222           No          No           No            No       No
#
#              miglitol troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 2278392            No           No         No      No          No      No
# 149190             No           No         No      No          No      Up
# 64410              No           No         No      No          No      No
# 500364             No           No         No      No          No      Up
# 16680              No           No         No      No          No  Steady
# ...               ...          ...        ...     ...         ...     ...
# 443847548          No           No         No      No          No    Down
# 443847782          No           No         No      No          No  Steady
# 443854148          No           No         No      No          No    Down
# 443857166          No           No         No      No          No      Up
# 443867222          No           No         No      No          No      No
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 2278392                       No                  No                       No
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
# ...                          ...                 ...                      ...
# 443847548                     No                  No                       No
# 443847782                     No                  No                       No
# 443854148                     No                  No                       No
# 443857166                     No                  No                       No
# 443867222                     No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 2278392                           No                     No     No
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
# ...                              ...                    ...    ...
# 443847548                         No                     No     Ch
# 443847782                         No                     No     No
# 443854148                         No                     No     Ch
# 443857166                         No                     No     Ch
# 443867222                         No                     No     No
#
#              diabetesMed readmitted
# encounter_id
# 2278392               No         NO
# 149190               Yes         NO
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO
# ...                  ...        ...
# 443847548            Yes         NO
# 443847782            Yes         NO
# 443854148            Yes         NO
# 443857166            Yes         NO
# 443867222             No         NO
#
# [99343 rows x 49 columns]

# %%
for col in ['diag_1', 'diag_2', 'diag_3']:
    df1[col].replace(oldlist, newlist, inplace=True)
    df1.loc[df1[col].str.contains('V', na=False), col] = 'Supplementary Classification of Factors Influencing Health Status and Contact with Health Services'

# %%
for col in ['diag_1', 'diag_2', 'diag_3']:
    df1[col].replace(oldlist, newlist, inplace=True)
    df1.loc[df1[col].str.contains('250', na=False), col] = 'Diabetes'

# %%
for col in ['diag_1', 'diag_2', 'diag_3']:
    df1[col].replace(oldlist, newlist, inplace=True)
    df1.loc[df1[col].str.contains('E', na=False), col] = 'External Causes of Injuries and Poisonings'

# %%
df1
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)    NaN
# 149190           55629189        Caucasian  Female  [10-20)    NaN
# 64410            86047875  AfricanAmerican  Female  [20-30)    NaN
# 500364           82442376        Caucasian    Male  [30-40)    NaN
# 16680            42519267        Caucasian    Male  [40-50)    NaN
# ...                   ...              ...     ...      ...    ...
# 443847548       100162476  AfricanAmerican    Male  [70-80)    NaN
# 443847782        74694222  AfricanAmerican  Female  [80-90)    NaN
# 443854148        41088789        Caucasian    Male  [70-80)    NaN
# 443857166        31693671        Caucasian  Female  [80-90)    NaN
# 443867222       175429310        Caucasian    Male  [70-80)    NaN
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
# ...                         ...                       ...
# 443847548                     1                         3
# 443847782                     1                         4
# 443854148                     1                         1
# 443857166                     2                         3
# 443867222                     1                         1
#
#               admission_source_id  time_in_hospital payer_code  \
# encounter_id
# 2278392                         1                 1        NaN
# 149190                          7                 3        NaN
# 64410                           7                 2        NaN
# 500364                          7                 2        NaN
# 16680                           7                 1        NaN
# ...                           ...               ...        ...
# 443847548                       7                 3         MC
# 443847782                       5                 5         MC
# 443854148                       7                 1         MC
# 443857166                       7                10         MC
# 443867222                       7                 6        NaN
#
#                      medical_specialty  num_lab_procedures  num_procedures  \
# encounter_id
# 2278392       Pediatrics-Endocrinology                  41               0
# 149190                             NaN                  59               0
# 64410                              NaN                  11               5
# 500364                             NaN                  44               1
# 16680                              NaN                  51               0
# ...                                ...                 ...             ...
# 443847548                          NaN                  51               0
# 443847782                          NaN                  33               3
# 443854148                          NaN                  53               0
# 443857166              Surgery-General                  45               2
# 443867222                          NaN                  13               3
#
#               num_medications  number_outpatient  number_emergency  \
# encounter_id
# 2278392                     1                  0                 0
# 149190                     18                  0                 0
# 64410                      13                  2                 0
# 500364                     16                  0                 0
# 16680                       8                  0                 0
# ...                       ...                ...               ...
# 443847548                  16                  0                 0
# 443847782                  18                  0                 0
# 443854148                   9                  1                 0
# 443857166                  21                  0                 0
# 443867222                   3                  0                 0
#
#               number_inpatient  \
# encounter_id
# 2278392                      0
# 149190                       0
# 64410                        1
# 500364                       0
# 16680                        0
# ...                        ...
# 443847548                    0
# 443847782                    1
# 443854148                    0
# 443857166                    1
# 443867222                    0
#
#                                                          diag_1  \
# encounter_id
# 2278392                                                Diabetes
# 149190               External Causes of Injuries and Poisonings
# 64410         Complications Of Pregnancy, Childbirth, And Th...
# 500364                        Infectious And Parasitic Diseases
# 16680                                                 Neoplasms
# ...                                                         ...
# 443847548                                              Diabetes
# 443847782                      Diseases Of The Digestive System
# 443854148                     Infectious And Parasitic Diseases
# 443857166                                  Injury And Poisoning
# 443867222                      Diseases Of The Digestive System
#
#                                                       diag_2  \
# encounter_id
# 2278392                                                  NaN
# 149190                                              Diabetes
# 64410             External Causes of Injuries and Poisonings
# 500364                                              Diabetes
# 16680                                              Neoplasms
# ...                                                      ...
# 443847548                                   Mental Disorders
# 443847782         External Causes of Injuries and Poisonings
# 443854148               Diseases Of The Genitourinary System
# 443857166     Diseases Of The Blood And Blood-Forming Organs
# 443867222                   Diseases Of The Digestive System
#
#                                                          diag_3  \
# encounter_id
# 2278392                                                     NaN
# 149190               External Causes of Injuries and Poisonings
# 64410         Supplementary Classification of Factors Influe...
# 500364                       Diseases Of The Circulatory System
# 16680                External Causes of Injuries and Poisonings
# ...                                                         ...
# 443847548                    Diseases Of The Circulatory System
# 443847782           Symptoms, Signs, And Ill-Defined Conditions
# 443854148                                      Mental Disorders
# 443857166                                  Injury And Poisoning
# 443867222           Symptoms, Signs, And Ill-Defined Conditions
#
#               number_diagnoses max_glu_serum A1Cresult metformin repaglinide  \
# encounter_id
# 2278392                      1          None      None        No          No
# 149190                       9          None      None        No          No
# 64410                        6          None      None        No          No
# 500364                       7          None      None        No          No
# 16680                        5          None      None        No          No
# ...                        ...           ...       ...       ...         ...
# 443847548                    9          None        >8    Steady          No
# 443847782                    9          None      None        No          No
# 443854148                   13          None      None    Steady          No
# 443857166                    9          None      None        No          No
# 443867222                    9          None      None        No          No
#
#              nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# encounter_id
# 2278392               No             No          No            No        No
# 149190                No             No          No            No        No
# 64410                 No             No          No            No    Steady
# 500364                No             No          No            No        No
# 16680                 No             No          No            No    Steady
# ...                  ...            ...         ...           ...       ...
# 443847548             No             No          No            No        No
# 443847782             No             No          No            No        No
# 443854148             No             No          No            No        No
# 443857166             No             No          No            No    Steady
# 443867222             No             No          No            No        No
#
#              glyburide tolbutamide pioglitazone rosiglitazone acarbose  \
# encounter_id
# 2278392             No          No           No            No       No
# 149190              No          No           No            No       No
# 64410               No          No           No            No       No
# 500364              No          No           No            No       No
# 16680               No          No           No            No       No
# ...                ...         ...          ...           ...      ...
# 443847548           No          No           No            No       No
# 443847782           No          No           No            No       No
# 443854148           No          No           No            No       No
# 443857166           No          No       Steady            No       No
# 443867222           No          No           No            No       No
#
#              miglitol troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 2278392            No           No         No      No          No      No
# 149190             No           No         No      No          No      Up
# 64410              No           No         No      No          No      No
# 500364             No           No         No      No          No      Up
# 16680              No           No         No      No          No  Steady
# ...               ...          ...        ...     ...         ...     ...
# 443847548          No           No         No      No          No    Down
# 443847782          No           No         No      No          No  Steady
# 443854148          No           No         No      No          No    Down
# 443857166          No           No         No      No          No      Up
# 443867222          No           No         No      No          No      No
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 2278392                       No                  No                       No
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
# ...                          ...                 ...                      ...
# 443847548                     No                  No                       No
# 443847782                     No                  No                       No
# 443854148                     No                  No                       No
# 443857166                     No                  No                       No
# 443867222                     No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 2278392                           No                     No     No
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
# ...                              ...                    ...    ...
# 443847548                         No                     No     Ch
# 443847782                         No                     No     No
# 443854148                         No                     No     Ch
# 443857166                         No                     No     Ch
# 443867222                         No                     No     No
#
#              diabetesMed readmitted
# encounter_id
# 2278392               No         NO
# 149190               Yes         NO
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO
# ...                  ...        ...
# 443847548            Yes         NO
# 443847782            Yes         NO
# 443854148            Yes         NO
# 443857166            Yes         NO
# 443867222             No         NO
#
# [99343 rows x 49 columns]

# %%
df2=df1.drop(columns=['weight', 'payer_code',"medical_specialty"])

# %%
df2=df2.dropna()
df2
# Out:
#               patient_nbr             race  gender      age  \
# encounter_id
# 149190           55629189        Caucasian  Female  [10-20)
# 64410            86047875  AfricanAmerican  Female  [20-30)
# 500364           82442376        Caucasian    Male  [30-40)
# 16680            42519267        Caucasian    Male  [40-50)
# 35754            82637451        Caucasian    Male  [50-60)
# ...                   ...              ...     ...      ...
# 443847548       100162476  AfricanAmerican    Male  [70-80)
# 443847782        74694222  AfricanAmerican  Female  [80-90)
# 443854148        41088789        Caucasian    Male  [70-80)
# 443857166        31693671        Caucasian  Female  [80-90)
# 443867222       175429310        Caucasian    Male  [70-80)
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
# 35754                         2                         1
# ...                         ...                       ...
# 443847548                     1                         3
# 443847782                     1                         4
# 443854148                     1                         1
# 443857166                     2                         3
# 443867222                     1                         1
#
#               admission_source_id  time_in_hospital  num_lab_procedures  \
# encounter_id
# 149190                          7                 3                  59
# 64410                           7                 2                  11
# 500364                          7                 2                  44
# 16680                           7                 1                  51
# 35754                           2                 3                  31
# ...                           ...               ...                 ...
# 443847548                       7                 3                  51
# 443847782                       5                 5                  33
# 443854148                       7                 1                  53
# 443857166                       7                10                  45
# 443867222                       7                 6                  13
#
#               num_procedures  num_medications  number_outpatient  \
# encounter_id
# 149190                     0               18                  0
# 64410                      5               13                  2
# 500364                     1               16                  0
# 16680                      0                8                  0
# 35754                      6               16                  0
# ...                      ...              ...                ...
# 443847548                  0               16                  0
# 443847782                  3               18                  0
# 443854148                  0                9                  1
# 443857166                  2               21                  0
# 443867222                  3                3                  0
#
#               number_emergency  number_inpatient  \
# encounter_id
# 149190                       0                 0
# 64410                        0                 1
# 500364                       0                 0
# 16680                        0                 0
# 35754                        0                 0
# ...                        ...               ...
# 443847548                    0                 0
# 443847782                    0                 1
# 443854148                    0                 0
# 443857166                    0                 1
# 443867222                    0                 0
#
#                                                          diag_1  \
# encounter_id
# 149190               External Causes of Injuries and Poisonings
# 64410         Complications Of Pregnancy, Childbirth, And Th...
# 500364                        Infectious And Parasitic Diseases
# 16680                                                 Neoplasms
# 35754                        Diseases Of The Circulatory System
# ...                                                         ...
# 443847548                                              Diabetes
# 443847782                      Diseases Of The Digestive System
# 443854148                     Infectious And Parasitic Diseases
# 443857166                                  Injury And Poisoning
# 443867222                      Diseases Of The Digestive System
#
#                                                       diag_2  \
# encounter_id
# 149190                                              Diabetes
# 64410             External Causes of Injuries and Poisonings
# 500364                                              Diabetes
# 16680                                              Neoplasms
# 35754                     Diseases Of The Circulatory System
# ...                                                      ...
# 443847548                                   Mental Disorders
# 443847782         External Causes of Injuries and Poisonings
# 443854148               Diseases Of The Genitourinary System
# 443857166     Diseases Of The Blood And Blood-Forming Organs
# 443867222                   Diseases Of The Digestive System
#
#                                                          diag_3  \
# encounter_id
# 149190               External Causes of Injuries and Poisonings
# 64410         Supplementary Classification of Factors Influe...
# 500364                       Diseases Of The Circulatory System
# 16680                External Causes of Injuries and Poisonings
# 35754                External Causes of Injuries and Poisonings
# ...                                                         ...
# 443847548                    Diseases Of The Circulatory System
# 443847782           Symptoms, Signs, And Ill-Defined Conditions
# 443854148                                      Mental Disorders
# 443857166                                  Injury And Poisoning
# 443867222           Symptoms, Signs, And Ill-Defined Conditions
#
#               number_diagnoses max_glu_serum A1Cresult metformin repaglinide  \
# encounter_id
# 149190                       9          None      None        No          No
# 64410                        6          None      None        No          No
# 500364                       7          None      None        No          No
# 16680                        5          None      None        No          No
# 35754                        9          None      None        No          No
# ...                        ...           ...       ...       ...         ...
# 443847548                    9          None        >8    Steady          No
# 443847782                    9          None      None        No          No
# 443854148                   13          None      None    Steady          No
# 443857166                    9          None      None        No          No
# 443867222                    9          None      None        No          No
#
#              nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# encounter_id
# 149190                No             No          No            No        No
# 64410                 No             No          No            No    Steady
# 500364                No             No          No            No        No
# 16680                 No             No          No            No    Steady
# 35754                 No             No          No            No        No
# ...                  ...            ...         ...           ...       ...
# 443847548             No             No          No            No        No
# 443847782             No             No          No            No        No
# 443854148             No             No          No            No        No
# 443857166             No             No          No            No    Steady
# 443867222             No             No          No            No        No
#
#              glyburide tolbutamide pioglitazone rosiglitazone acarbose  \
# encounter_id
# 149190              No          No           No            No       No
# 64410               No          No           No            No       No
# 500364              No          No           No            No       No
# 16680               No          No           No            No       No
# 35754               No          No           No            No       No
# ...                ...         ...          ...           ...      ...
# 443847548           No          No           No            No       No
# 443847782           No          No           No            No       No
# 443854148           No          No           No            No       No
# 443857166           No          No       Steady            No       No
# 443867222           No          No           No            No       No
#
#              miglitol troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 149190             No           No         No      No          No      Up
# 64410              No           No         No      No          No      No
# 500364             No           No         No      No          No      Up
# 16680              No           No         No      No          No  Steady
# 35754              No           No         No      No          No  Steady
# ...               ...          ...        ...     ...         ...     ...
# 443847548          No           No         No      No          No    Down
# 443847782          No           No         No      No          No  Steady
# 443854148          No           No         No      No          No    Down
# 443857166          No           No         No      No          No      Up
# 443867222          No           No         No      No          No      No
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
# 35754                         No                  No                       No
# ...                          ...                 ...                      ...
# 443847548                     No                  No                       No
# 443847782                     No                  No                       No
# 443854148                     No                  No                       No
# 443857166                     No                  No                       No
# 443867222                     No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
# 35754                             No                     No     No
# ...                              ...                    ...    ...
# 443847548                         No                     No     Ch
# 443847782                         No                     No     No
# 443854148                         No                     No     Ch
# 443857166                         No                     No     Ch
# 443867222                         No                     No     No
#
#              diabetesMed readmitted
# encounter_id
# 149190               Yes         NO
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO
# 35754                Yes         NO
# ...                  ...        ...
# 443847548            Yes         NO
# 443847782            Yes         NO
# 443854148            Yes         NO
# 443857166            Yes         NO
# 443867222             No         NO
#
# [95673 rows x 46 columns]

# %%
print(df2['diag_1'].unique())
# Out:
# ['External Causes of Injuries and Poisonings'
#  'Complications Of Pregnancy, Childbirth, And The Puerperium'
#  'Infectious And Parasitic Diseases' 'Neoplasms'
#  'Diseases Of The Circulatory System' 'Diabetes'
#  'Diseases Of The Respiratory System' 'Injury And Poisoning'
#  'Diseases Of The Skin And Subcutaneous Tissue'
#  'Supplementary Classification of Factors Influencing Health Status and Contact with Health Services'
#  'Symptoms, Signs, And Ill-Defined Conditions'
#  'Diseases Of The Genitourinary System' 'Mental Disorders'
#  'Diseases Of The Musculoskeletal System And Connective Tissue'
#  'Diseases Of The Digestive System'
#  'Diseases Of The Nervous System And Sense Organs'
#  'Diseases Of The Blood And Blood-Forming Organs' 'Congential Anomalies']

# %%
#df2["age"],_=pd.factorize(df2['age'], sort=True), 0:(0-10),1:(10-20),2:(20-30),3:(30-40),4:(40-50),5:(50-60),6:(60-70),
#                                                   7:(70-80),8:(80-90)

###0:<30    1:>30   2:No
#df2["readmitted"],_=pd.factorize(df2['readmitted'],sort=True)
df2[["race","gender","age","admission_type_id","discharge_disposition_id","admission_source_id",
    "max_glu_serum","A1Cresult","metformin","repaglinide","nateglinide","chlorpropamide","glimepiride","acetohexamide",
     "glipizide","glyburide","tolbutamide","pioglitazone","rosiglitazone","acarbose","miglitol","troglitazone","tolazamide",
     "examide","citoglipton","insulin","glyburide","metformin","glipizide","metformin","glimepiride","pioglitazone","metformin",
     "rosiglitazone","metformin","pioglitazone","change","diabetesMed","readmitted"
    ]].apply(lambda x: x.astype('category'))
df2
# Out:
#               patient_nbr             race  gender      age  \
# encounter_id
# 149190           55629189        Caucasian  Female  [10-20)
# 64410            86047875  AfricanAmerican  Female  [20-30)
# 500364           82442376        Caucasian    Male  [30-40)
# 16680            42519267        Caucasian    Male  [40-50)
# 35754            82637451        Caucasian    Male  [50-60)
# ...                   ...              ...     ...      ...
# 443847548       100162476  AfricanAmerican    Male  [70-80)
# 443847782        74694222  AfricanAmerican  Female  [80-90)
# 443854148        41088789        Caucasian    Male  [70-80)
# 443857166        31693671        Caucasian  Female  [80-90)
# 443867222       175429310        Caucasian    Male  [70-80)
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
# 35754                         2                         1
# ...                         ...                       ...
# 443847548                     1                         3
# 443847782                     1                         4
# 443854148                     1                         1
# 443857166                     2                         3
# 443867222                     1                         1
#
#               admission_source_id  time_in_hospital  num_lab_procedures  \
# encounter_id
# 149190                          7                 3                  59
# 64410                           7                 2                  11
# 500364                          7                 2                  44
# 16680                           7                 1                  51
# 35754                           2                 3                  31
# ...                           ...               ...                 ...
# 443847548                       7                 3                  51
# 443847782                       5                 5                  33
# 443854148                       7                 1                  53
# 443857166                       7                10                  45
# 443867222                       7                 6                  13
#
#               num_procedures  num_medications  number_outpatient  \
# encounter_id
# 149190                     0               18                  0
# 64410                      5               13                  2
# 500364                     1               16                  0
# 16680                      0                8                  0
# 35754                      6               16                  0
# ...                      ...              ...                ...
# 443847548                  0               16                  0
# 443847782                  3               18                  0
# 443854148                  0                9                  1
# 443857166                  2               21                  0
# 443867222                  3                3                  0
#
#               number_emergency  number_inpatient  \
# encounter_id
# 149190                       0                 0
# 64410                        0                 1
# 500364                       0                 0
# 16680                        0                 0
# 35754                        0                 0
# ...                        ...               ...
# 443847548                    0                 0
# 443847782                    0                 1
# 443854148                    0                 0
# 443857166                    0                 1
# 443867222                    0                 0
#
#                                                          diag_1  \
# encounter_id
# 149190               External Causes of Injuries and Poisonings
# 64410         Complications Of Pregnancy, Childbirth, And Th...
# 500364                        Infectious And Parasitic Diseases
# 16680                                                 Neoplasms
# 35754                        Diseases Of The Circulatory System
# ...                                                         ...
# 443847548                                              Diabetes
# 443847782                      Diseases Of The Digestive System
# 443854148                     Infectious And Parasitic Diseases
# 443857166                                  Injury And Poisoning
# 443867222                      Diseases Of The Digestive System
#
#                                                       diag_2  \
# encounter_id
# 149190                                              Diabetes
# 64410             External Causes of Injuries and Poisonings
# 500364                                              Diabetes
# 16680                                              Neoplasms
# 35754                     Diseases Of The Circulatory System
# ...                                                      ...
# 443847548                                   Mental Disorders
# 443847782         External Causes of Injuries and Poisonings
# 443854148               Diseases Of The Genitourinary System
# 443857166     Diseases Of The Blood And Blood-Forming Organs
# 443867222                   Diseases Of The Digestive System
#
#                                                          diag_3  \
# encounter_id
# 149190               External Causes of Injuries and Poisonings
# 64410         Supplementary Classification of Factors Influe...
# 500364                       Diseases Of The Circulatory System
# 16680                External Causes of Injuries and Poisonings
# 35754                External Causes of Injuries and Poisonings
# ...                                                         ...
# 443847548                    Diseases Of The Circulatory System
# 443847782           Symptoms, Signs, And Ill-Defined Conditions
# 443854148                                      Mental Disorders
# 443857166                                  Injury And Poisoning
# 443867222           Symptoms, Signs, And Ill-Defined Conditions
#
#               number_diagnoses max_glu_serum A1Cresult metformin repaglinide  \
# encounter_id
# 149190                       9          None      None        No          No
# 64410                        6          None      None        No          No
# 500364                       7          None      None        No          No
# 16680                        5          None      None        No          No
# 35754                        9          None      None        No          No
# ...                        ...           ...       ...       ...         ...
# 443847548                    9          None        >8    Steady          No
# 443847782                    9          None      None        No          No
# 443854148                   13          None      None    Steady          No
# 443857166                    9          None      None        No          No
# 443867222                    9          None      None        No          No
#
#              nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# encounter_id
# 149190                No             No          No            No        No
# 64410                 No             No          No            No    Steady
# 500364                No             No          No            No        No
# 16680                 No             No          No            No    Steady
# 35754                 No             No          No            No        No
# ...                  ...            ...         ...           ...       ...
# 443847548             No             No          No            No        No
# 443847782             No             No          No            No        No
# 443854148             No             No          No            No        No
# 443857166             No             No          No            No    Steady
# 443867222             No             No          No            No        No
#
#              glyburide tolbutamide pioglitazone rosiglitazone acarbose  \
# encounter_id
# 149190              No          No           No            No       No
# 64410               No          No           No            No       No
# 500364              No          No           No            No       No
# 16680               No          No           No            No       No
# 35754               No          No           No            No       No
# ...                ...         ...          ...           ...      ...
# 443847548           No          No           No            No       No
# 443847782           No          No           No            No       No
# 443854148           No          No           No            No       No
# 443857166           No          No       Steady            No       No
# 443867222           No          No           No            No       No
#
#              miglitol troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 149190             No           No         No      No          No      Up
# 64410              No           No         No      No          No      No
# 500364             No           No         No      No          No      Up
# 16680              No           No         No      No          No  Steady
# 35754              No           No         No      No          No  Steady
# ...               ...          ...        ...     ...         ...     ...
# 443847548          No           No         No      No          No    Down
# 443847782          No           No         No      No          No  Steady
# 443854148          No           No         No      No          No    Down
# 443857166          No           No         No      No          No      Up
# 443867222          No           No         No      No          No      No
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
# 35754                         No                  No                       No
# ...                          ...                 ...                      ...
# 443847548                     No                  No                       No
# 443847782                     No                  No                       No
# 443854148                     No                  No                       No
# 443857166                     No                  No                       No
# 443867222                     No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
# 35754                             No                     No     No
# ...                              ...                    ...    ...
# 443847548                         No                     No     Ch
# 443847782                         No                     No     No
# 443854148                         No                     No     Ch
# 443857166                         No                     No     Ch
# 443867222                         No                     No     No
#
#              diabetesMed readmitted
# encounter_id
# 149190               Yes         NO
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO
# 35754                Yes         NO
# ...                  ...        ...
# 443847548            Yes         NO
# 443847782            Yes         NO
# 443854148            Yes         NO
# 443857166            Yes         NO
# 443867222             No         NO
#
# [95673 rows x 46 columns]

# %%
df2['admission_type_id'] = df2.admission_type_id.astype('object')
df2['discharge_disposition_id'] = df2.discharge_disposition_id.astype('object')
df2['admission_source_id'] = df2.admission_source_id.astype('object')
df2.dtypes
# Out:
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# admission_type_id           object
# discharge_disposition_id    object
# admission_source_id         object
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
import seaborn as sns
corr = df2.corr(method="pearson")
print(corr)
sns.heatmap(corr)
# Out:
#                     patient_nbr  time_in_hospital  num_lab_procedures  \
# patient_nbr            1.000000         -0.030924            0.009300
# time_in_hospital      -0.030924          1.000000            0.320161
# num_lab_procedures     0.009300          0.320161            1.000000
# num_procedures        -0.023585          0.189407            0.052338
# num_medications        0.011261          0.461774            0.264941
# number_outpatient      0.102240         -0.011209           -0.008587
# number_emergency       0.061510         -0.010384           -0.000776
# number_inpatient       0.010778          0.072973            0.039914
# number_diagnoses       0.215057          0.211514            0.147362
#
#                     num_procedures  num_medications  number_outpatient  \
# patient_nbr              -0.023585         0.011261           0.102240
# time_in_hospital          0.189407         0.461774          -0.011209
# num_lab_procedures        0.052338         0.264941          -0.008587
# num_procedures            1.000000         0.378960          -0.026948
# num_medications           0.378960         1.000000           0.043492
# number_outpatient        -0.026948         0.043492           1.000000
# number_emergency         -0.039288         0.012973           0.091247
# number_inpatient         -0.068376         0.063981           0.106657
# number_diagnoses          0.055406         0.241369           0.092080
#
#                     number_emergency  number_inpatient  number_diagnoses
# patient_nbr                 0.061510          0.010778          0.215057
# time_in_hospital           -0.010384          0.072973          0.211514
# num_lab_procedures         -0.000776          0.039914          0.147362
# num_procedures             -0.039288         -0.068376          0.055406
# num_medications             0.012973          0.063981          0.241369
# number_outpatient           0.091247          0.106657          0.092080
# number_emergency            1.000000          0.268349          0.055067
# number_inpatient            0.268349          1.000000          0.101269
# number_diagnoses            0.055067          0.101269          1.000000

# %%
df2["readmitted"]
# Out:
# encounter_id
# 149190       NO
# 64410        NO
# 500364       NO
# 16680        NO
# 35754        NO
#              ..
# 443847548    NO
# 443847782    NO
# 443854148    NO
# 443857166    NO
# 443867222    NO
# Name: readmitted, Length: 95673, dtype: object

# %%
df2.iloc[12]
# Out:
# patient_nbr                                           77586282
# race                                                 Caucasian
# gender                                                    Male
# age                                                    [80-90)
# admission_type_id                                            1
# discharge_disposition_id                                     6
# admission_source_id                                          7
# time_in_hospital                                            10
# num_lab_procedures                                          55
# num_procedures                                               1
# num_medications                                             31
# number_outpatient                                            0
# number_emergency                                             0
# number_inpatient                                             0
# diag_1                      Diseases Of The Circulatory System
# diag_2                      Diseases Of The Circulatory System
# diag_3                      Diseases Of The Circulatory System
# number_diagnoses                                             8
# max_glu_serum                                             None
# A1Cresult                                                 None
# metformin                                                   No
# repaglinide                                                 No
# nateglinide                                                 No
# chlorpropamide                                              No
# glimepiride                                                 No
# acetohexamide                                               No
# glipizide                                                   No
# glyburide                                                   No
# tolbutamide                                                 No
# pioglitazone                                                No
# rosiglitazone                                               No
# acarbose                                                    No
# miglitol                                                    No
# troglitazone                                                No
# tolazamide                                                  No
# examide                                                     No
# citoglipton                                                 No
# insulin                                                 Steady
# glyburide-metformin                                         No
# glipizide-metformin                                         No
# glimepiride-pioglitazone                                    No
# metformin-rosiglitazone                                     No
# metformin-pioglitazone                                      No
# change                                                      No
# diabetesMed                                                Yes
# readmitted                                                  NO
# Name: 42570, dtype: object

# %%
cat_columns = df2.select_dtypes(['object']).columns
df2[cat_columns] = df2[cat_columns].astype('category')
df2[cat_columns] = df2[cat_columns].apply(lambda x : x.cat.codes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-3dbe214c7568> in <module>
#       1 cat_columns = df2.select_dtypes(['object']).columns
# ----> 2 df2[cat_columns] = df2[cat_columns].astype('category')
#       3 df2[cat_columns] = df2[cat_columns].apply(lambda x : x.cat.codes)
#       4 df2.head()
#
# D:\anacod\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5885
#    5886         # GH 19920: retain column metadata after concat
# -> 5887         result = pd.concat(results, axis=1, copy=False)
#    5888         result.columns = self.columns
#    5889         return result
#
# D:\anacod\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# D:\anacod\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     302
#     303         if len(objs) == 0:
# --> 304             raise ValueError("No objects to concatenate")
#     305
#     306         if keys is None:
#
# ValueError: No objects to concatenate

# %%
df2 = df2.drop(columns=['patient_nbr'])
df2.head()
# Out:
#               race  gender  age  admission_type_id  discharge_disposition_id  \
# encounter_id
# 149190           2       0    1                  0                         0
# 64410            0       0    2                  0                         0
# 500364           2       1    3                  0                         0
# 16680            2       1    4                  0                         0
# 35754            2       1    5                  1                         0
#
#               admission_source_id  time_in_hospital  num_lab_procedures  \
# encounter_id
# 149190                          6                 3                  59
# 64410                           6                 2                  11
# 500364                          6                 2                  44
# 16680                           6                 1                  51
# 35754                           1                 3                  31
#
#               num_procedures  num_medications  number_outpatient  \
# encounter_id
# 149190                     0               18                  0
# 64410                      5               13                  2
# 500364                     1               16                  0
# 16680                      0                8                  0
# 35754                      6               16                  0
#
#               number_emergency  number_inpatient  diag_1  diag_2  diag_3  \
# encounter_id
# 149190                       0                 0      11       2      12
# 64410                        0                 1       0      11      17
# 500364                       0                 0      12       2       5
# 16680                        0                 0      15      15      12
# 35754                        0                 0       4       4      12
#
#               number_diagnoses  max_glu_serum  A1Cresult  metformin  \
# encounter_id
# 149190                       9              2          2          1
# 64410                        6              2          2          1
# 500364                       7              2          2          1
# 16680                        5              2          2          1
# 35754                        9              2          2          1
#
#               repaglinide  nateglinide  chlorpropamide  glimepiride  \
# encounter_id
# 149190                  1            1               1            1
# 64410                   1            1               1            1
# 500364                  1            1               1            1
# 16680                   1            1               1            1
# 35754                   1            1               1            1
#
#               acetohexamide  glipizide  glyburide  tolbutamide  pioglitazone  \
# encounter_id
# 149190                    0          1          1            0             1
# 64410                     0          2          1            0             1
# 500364                    0          1          1            0             1
# 16680                     0          2          1            0             1
# 35754                     0          1          1            0             1
#
#               rosiglitazone  acarbose  miglitol  troglitazone  tolazamide  \
# encounter_id
# 149190                    1         1         1             0           0
# 64410                     1         1         1             0           0
# 500364                    1         1         1             0           0
# 16680                     1         1         1             0           0
# 35754                     1         1         1             0           0
#
#               examide  citoglipton  insulin  glyburide-metformin  \
# encounter_id
# 149190              0            0        3                    1
# 64410               0            0        1                    1
# 500364              0            0        3                    1
# 16680               0            0        2                    1
# 35754               0            0        2                    1
#
#               glipizide-metformin  glimepiride-pioglitazone  \
# encounter_id
# 149190                          0                         0
# 64410                           0                         0
# 500364                          0                         0
# 16680                           0                         0
# 35754                           0                         0
#
#               metformin-rosiglitazone  metformin-pioglitazone  change  \
# encounter_id
# 149190                              0                       0       0
# 64410                               0                       0       1
# 500364                              0                       0       0
# 16680                               0                       0       0
# 35754                               0                       0       1
#
#               diabetesMed  readmitted
# encounter_id
# 149190                  1           1
# 64410                   1           1
# 500364                  1           1
# 16680                   1           1
# 35754                   1           1

# %%
#############################random Forest
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
dataset = df2.to_numpy().astype(float)
x = dataset[:,0:-1]
y = dataset[:,-1]
 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=24)

# %%
from sklearn.preprocessing import StandardScaler

readmitted=df2.readmitted
readmitted
x1 = pd.get_dummies(df2.drop(columns=['readmitted']))
x1
sns.countplot(readmitted)

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
x_scaled = x.copy()
x_scaled = scaler.fit_transform(x_scaled)
print(x_scaled)
# Out:
# [[ 3.95937539e-01 -9.24248730e-01 -3.27362306e+00 ... -3.23301391e-03
#   -1.07445690e+00  5.45458450e-01]
#  [-1.92538686e+00 -9.24248730e-01 -2.63223399e+00 ... -3.23301391e-03
#    9.30702758e-01  5.45458450e-01]
#  [ 3.95937539e-01  1.08186881e+00 -1.99084491e+00 ... -3.23301391e-03
#   -1.07445690e+00  5.45458450e-01]
#  ...
#  [ 3.95937539e-01  1.08186881e+00  5.74711370e-01 ... -3.23301391e-03
#   -1.07445690e+00  5.45458450e-01]
#  [ 3.95937539e-01 -9.24248730e-01  1.21610044e+00 ... -3.23301391e-03
#   -1.07445690e+00  5.45458450e-01]
#  [ 3.95937539e-01  1.08186881e+00  5.74711370e-01 ... -3.23301391e-03
#    9.30702758e-01 -1.83332021e+00]]

# %%
x_train_scaled = x_train.copy()
x_test_scaled = x_test.copy()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
#######################
# preprocessing data #
#####################
np.savetxt("x_train.csv",x_train_scaled,delimiter=",")

# %%
from sklearn import metrics
randomforest = RandomForestClassifier(class_weight='balanced')
randomforest.fit(x_train, y_train)
y_pred = randomforest.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
# Out:
# D:\anacod\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.03      0.05      2740
#          1.0       0.89      0.99      0.94     21179
#
#     accuracy                           0.88     23919
#    macro avg       0.57      0.51      0.49     23919
# weighted avg       0.81      0.88      0.83     23919

# %%
from sklearn import metrics
randomforest = RandomForestClassifier(random_state=42,n_estimators=500)
randomforest.fit(x_train, y_train)
y_pred = randomforest.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.01      0.01      2740
#          1.0       0.89      1.00      0.94     21179
#
#     accuracy                           0.89     23919
#    macro avg       0.69      0.50      0.48     23919
# weighted avg       0.84      0.89      0.83     23919

# %%
randomforest = RandomForestClassifier(n_estimators=200, min_samples_split=20)
randomforest.fit(x_train, y_train)
y_pred = randomforest.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          <30       0.25      0.00      0.00      2767
#           NO       0.89      1.00      0.94     21747
#
#     accuracy                           0.89     24514
#    macro avg       0.57      0.50      0.47     24514
# weighted avg       0.82      0.89      0.83     24514

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[   16  2724]
#  [   17 21162]]

# %%
plt.figure(figsize=(9,9))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Reds_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(randomforest.score(x_test, y_test))
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 0.8854049082319495')

# %%
##############
# ROC Curve #
#############
from sklearn.metrics import roc_curve
fpr, tpr, thresholds=roc_curve(y_test, y_pred)
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label='Randomforest Classifier')
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='random', alpha=.8)
plt.xlim([0,1])
plt.ylim([0,1])
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))
plt.grid()
plt.legend()
plt.axes().set_aspect('equal')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# D:\anacod\lib\site-packages\ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Text(0, 0.5, 'True Positive Rate')

# %%
feature_names = df2.columns
feature_imports = randomforest.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(20, "Importance")
most_imp_features.sort_values(by="Importance", inplace=True)
plt.figure(figsize=(10,6))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Random Forest')
plt.show()
