# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from numpy import cov
from scipy import stats
import statsmodels.formula.api as smf
import seaborn as sns
from matplotlib import pyplot as plt
import imblearn 
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import os

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('data/diabetic_data.csv', index_col=0, parse_dates=True)
df.head()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)      ?
# 149190           55629189        Caucasian  Female  [10-20)      ?
# 64410            86047875  AfricanAmerican  Female  [20-30)      ?
# 500364           82442376        Caucasian    Male  [30-40)      ?
# 16680            42519267        Caucasian    Male  [40-50)      ?
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code  \
# encounter_id
# 2278392                         1                 1          ?
# 149190                          7                 3          ?
# 64410                           7                 2          ?
# 500364                          7                 2          ?
# 16680                           7                 1          ?
#
#                      medical_specialty  num_lab_procedures  num_procedures  \
# encounter_id
# 2278392       Pediatrics-Endocrinology                  41               0
# 149190                               ?                  59               0
# 64410                                ?                  11               5
# 500364                               ?                  44               1
# 16680                                ?                  51               0
#
#               num_medications  number_outpatient  number_emergency  \
# encounter_id
# 2278392                     1                  0                 0
# 149190                     18                  0                 0
# 64410                      13                  2                 0
# 500364                     16                  0                 0
# 16680                       8                  0                 0
#
#               number_inpatient  diag_1  diag_2 diag_3  number_diagnoses  \
# encounter_id
# 2278392                      0  250.83       ?      ?                 1
# 149190                       0     276  250.01    255                 9
# 64410                        1     648     250    V27                 6
# 500364                       0       8  250.43    403                 7
# 16680                        0     197     157    250                 5
#
#              max_glu_serum A1Cresult metformin repaglinide nateglinide  \
# encounter_id
# 2278392               None      None        No          No          No
# 149190                None      None        No          No          No
# 64410                 None      None        No          No          No
# 500364                None      None        No          No          No
# 16680                 None      None        No          No          No
#
#              chlorpropamide glimepiride acetohexamide glipizide glyburide  \
# encounter_id
# 2278392                  No          No            No        No        No
# 149190                   No          No            No        No        No
# 64410                    No          No            No    Steady        No
# 500364                   No          No            No        No        No
# 16680                    No          No            No    Steady        No
#
#              tolbutamide pioglitazone rosiglitazone acarbose miglitol  \
# encounter_id
# 2278392               No           No            No       No       No
# 149190                No           No            No       No       No
# 64410                 No           No            No       No       No
# 500364                No           No            No       No       No
# 16680                 No           No            No       No       No
#
#              troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 2278392                No         No      No          No      No
# 149190                 No         No      No          No      Up
# 64410                  No         No      No          No      No
# 500364                 No         No      No          No      Up
# 16680                  No         No      No          No  Steady
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 2278392                       No                  No                       No
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 2278392                           No                     No     No
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
#
#              diabetesMed readmitted
# encounter_id
# 2278392               No         NO
# 149190               Yes        >30
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO

# %%
missing_values = ["n/a", "na", "--","?"]
df= pd.read_csv("data/diabetic_data.csv",index_col=0, parse_dates=True,na_values = missing_values)
df["readmitted"].replace({">30": "NO"}, inplace=True)
df["readmitted"].replace({"<30": "Yes"}, inplace=True)
df.head()
# Out:
# D:\anacod\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)    NaN
# 149190           55629189        Caucasian  Female  [10-20)    NaN
# 64410            86047875  AfricanAmerican  Female  [20-30)    NaN
# 500364           82442376        Caucasian    Male  [30-40)    NaN
# 16680            42519267        Caucasian    Male  [40-50)    NaN
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code  \
# encounter_id
# 2278392                         1                 1        NaN
# 149190                          7                 3        NaN
# 64410                           7                 2        NaN
# 500364                          7                 2        NaN
# 16680                           7                 1        NaN
#
#                      medical_specialty  num_lab_procedures  num_procedures  \
# encounter_id
# 2278392       Pediatrics-Endocrinology                  41               0
# 149190                             NaN                  59               0
# 64410                              NaN                  11               5
# 500364                             NaN                  44               1
# 16680                              NaN                  51               0
#
#               num_medications  number_outpatient  number_emergency  \
# encounter_id
# 2278392                     1                  0                 0
# 149190                     18                  0                 0
# 64410                      13                  2                 0
# 500364                     16                  0                 0
# 16680                       8                  0                 0
#
#               number_inpatient  diag_1  diag_2 diag_3  number_diagnoses  \
# encounter_id
# 2278392                      0  250.83     NaN    NaN                 1
# 149190                       0     276  250.01    255                 9
# 64410                        1     648     250    V27                 6
# 500364                       0       8  250.43    403                 7
# 16680                        0     197     157    250                 5
#
#              max_glu_serum A1Cresult metformin repaglinide nateglinide  \
# encounter_id
# 2278392               None      None        No          No          No
# 149190                None      None        No          No          No
# 64410                 None      None        No          No          No
# 500364                None      None        No          No          No
# 16680                 None      None        No          No          No
#
#              chlorpropamide glimepiride acetohexamide glipizide glyburide  \
# encounter_id
# 2278392                  No          No            No        No        No
# 149190                   No          No            No        No        No
# 64410                    No          No            No    Steady        No
# 500364                   No          No            No        No        No
# 16680                    No          No            No    Steady        No
#
#              tolbutamide pioglitazone rosiglitazone acarbose miglitol  \
# encounter_id
# 2278392               No           No            No       No       No
# 149190                No           No            No       No       No
# 64410                 No           No            No       No       No
# 500364                No           No            No       No       No
# 16680                 No           No            No       No       No
#
#              troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 2278392                No         No      No          No      No
# 149190                 No         No      No          No      Up
# 64410                  No         No      No          No      No
# 500364                 No         No      No          No      Up
# 16680                  No         No      No          No  Steady
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 2278392                       No                  No                       No
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 2278392                           No                     No     No
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
#
#              diabetesMed readmitted
# encounter_id
# 2278392               No         NO
# 149190               Yes         NO
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO

# %%
df = df[((df.discharge_disposition_id != 11) & 
         (df.discharge_disposition_id != 13) &
         (df.discharge_disposition_id != 14) & 
         (df.discharge_disposition_id != 19) & 
         (df.discharge_disposition_id != 20) & 
         (df.discharge_disposition_id != 21))]

# %%
icd9code = [(1, 139),
            (140, 239),
            (240, 279),
            (280, 289),
            (290, 319),
            (320, 389),
            (390, 459),
            (460, 519),
            (520, 579),
            (580, 629),
            (630, 679),
            (680, 709),
            (710, 739),
            (740, 759),
            (760, 779),
            (780, 799),
            (800, 999)]
icd9codelist = ['Infectious And Parasitic Diseases',
                'Neoplasms',
                'Endocrine, Nutritional And Metabolic Diseases, And Immunity Disorders',
                'Diseases Of The Blood And Blood-Forming Organs',
                'Mental Disorders',
                'Diseases Of The Nervous System And Sense Organs',
                'Diseases Of The Circulatory System',
                'Diseases Of The Respiratory System',
                'Diseases Of The Digestive System',
                'Diseases Of The Genitourinary System',
                'Complications Of Pregnancy, Childbirth, And The Puerperium',
                'Diseases Of The Skin And Subcutaneous Tissue',
                'Diseases Of The Musculoskeletal System And Connective Tissue',
                'Congential Anomalies',
                'Certain Conditions Originating In The Perinatal Period',
                'Symptoms, Signs, And Ill-Defined Conditions',
                'Injury And Poisoning']
codes = zip(icd9code, icd9codelist)
codelist = set(codes)
codelist
# Out:
# {((1, 139), 'Infectious And Parasitic Diseases'),
#  ((140, 239), 'Neoplasms'),
#  ((240, 279),
#   'Endocrine, Nutritional And Metabolic Diseases, And Immunity Disorders'),
#  ((280, 289), 'Diseases Of The Blood And Blood-Forming Organs'),
#  ((290, 319), 'Mental Disorders'),
#  ((320, 389), 'Diseases Of The Nervous System And Sense Organs'),
#  ((390, 459), 'Diseases Of The Circulatory System'),
#  ((460, 519), 'Diseases Of The Respiratory System'),
#  ((520, 579), 'Diseases Of The Digestive System'),
#  ((580, 629), 'Diseases Of The Genitourinary System'),
#  ((630, 679), 'Complications Of Pregnancy, Childbirth, And The Puerperium'),
#  ((680, 709), 'Diseases Of The Skin And Subcutaneous Tissue'),
#  ((710, 739), 'Diseases Of The Musculoskeletal System And Connective Tissue'),
#  ((740, 759), 'Congential Anomalies'),
#  ((760, 779), 'Certain Conditions Originating In The Perinatal Period'),
#  ((780, 799), 'Symptoms, Signs, And Ill-Defined Conditions'),
#  ((800, 999), 'Injury And Poisoning')}

# %%
for num_range, diagnosis in codelist:
    oldlist = range(num_range[0], num_range[1]+1)
    oldlist = [str(x) for x in oldlist]
    newlist = [diagnosis] * len(oldlist)
    for col in ['diag_1', 'diag_2', 'diag_3']:
        df[col].replace(oldlist, newlist, inplace=True)
        
for col in ['diag_1', 'diag_2', 'diag_3']:
    df.loc[df[col].str.contains('V', na=False), col] = 'Supplementary Classification of Factors Influencing Health Status and Contact with Health Services'
    df.loc[df[col].str.contains('250', na=False), col] = 'Diabetes'
    df.loc[df[col].str.contains('E', na=False), col] = 'External Causes of Injuries and Poisonings'

# %%
df[['diag_1', 'diag_2', 'diag_3']]
# Out:
#                                                          diag_1  \
# encounter_id
# 2278392                                                Diabetes
# 149190               External Causes of Injuries and Poisonings
# 64410         Complications Of Pregnancy, Childbirth, And Th...
# 500364                        Infectious And Parasitic Diseases
# 16680                                                 Neoplasms
# ...                                                         ...
# 443847548                                              Diabetes
# 443847782                      Diseases Of The Digestive System
# 443854148                     Infectious And Parasitic Diseases
# 443857166                                  Injury And Poisoning
# 443867222                      Diseases Of The Digestive System
#
#                                                       diag_2  \
# encounter_id
# 2278392                                                  NaN
# 149190                                              Diabetes
# 64410             External Causes of Injuries and Poisonings
# 500364                                              Diabetes
# 16680                                              Neoplasms
# ...                                                      ...
# 443847548                                   Mental Disorders
# 443847782         External Causes of Injuries and Poisonings
# 443854148               Diseases Of The Genitourinary System
# 443857166     Diseases Of The Blood And Blood-Forming Organs
# 443867222                   Diseases Of The Digestive System
#
#                                                          diag_3
# encounter_id
# 2278392                                                     NaN
# 149190               External Causes of Injuries and Poisonings
# 64410         Supplementary Classification of Factors Influe...
# 500364                       Diseases Of The Circulatory System
# 16680                External Causes of Injuries and Poisonings
# ...                                                         ...
# 443847548                    Diseases Of The Circulatory System
# 443847782           Symptoms, Signs, And Ill-Defined Conditions
# 443854148                                      Mental Disorders
# 443857166                                  Injury And Poisoning
# 443867222           Symptoms, Signs, And Ill-Defined Conditions
#
# [99343 rows x 3 columns]

# %%
df = df.drop(columns=['patient_nbr','weight', 'payer_code',"medical_specialty"])

# %%
df.head()
# Out:
#                          race  gender      age  admission_type_id  \
# encounter_id
# 2278392             Caucasian  Female   [0-10)                  6
# 149190              Caucasian  Female  [10-20)                  1
# 64410         AfricanAmerican  Female  [20-30)                  1
# 500364              Caucasian    Male  [30-40)                  1
# 16680               Caucasian    Male  [40-50)                  1
#
#               discharge_disposition_id  admission_source_id  time_in_hospital  \
# encounter_id
# 2278392                             25                    1                 1
# 149190                               1                    7                 3
# 64410                                1                    7                 2
# 500364                               1                    7                 2
# 16680                                1                    7                 1
#
#               num_lab_procedures  num_procedures  num_medications  \
# encounter_id
# 2278392                       41               0                1
# 149190                        59               0               18
# 64410                         11               5               13
# 500364                        44               1               16
# 16680                         51               0                8
#
#               number_outpatient  number_emergency  number_inpatient  \
# encounter_id
# 2278392                       0                 0                 0
# 149190                        0                 0                 0
# 64410                         2                 0                 1
# 500364                        0                 0                 0
# 16680                         0                 0                 0
#
#                                                          diag_1  \
# encounter_id
# 2278392                                                Diabetes
# 149190               External Causes of Injuries and Poisonings
# 64410         Complications Of Pregnancy, Childbirth, And Th...
# 500364                        Infectious And Parasitic Diseases
# 16680                                                 Neoplasms
#
#                                                   diag_2  \
# encounter_id
# 2278392                                              NaN
# 149190                                          Diabetes
# 64410         External Causes of Injuries and Poisonings
# 500364                                          Diabetes
# 16680                                          Neoplasms
#
#                                                          diag_3  \
# encounter_id
# 2278392                                                     NaN
# 149190               External Causes of Injuries and Poisonings
# 64410         Supplementary Classification of Factors Influe...
# 500364                       Diseases Of The Circulatory System
# 16680                External Causes of Injuries and Poisonings
#
#               number_diagnoses max_glu_serum A1Cresult metformin repaglinide  \
# encounter_id
# 2278392                      1          None      None        No          No
# 149190                       9          None      None        No          No
# 64410                        6          None      None        No          No
# 500364                       7          None      None        No          No
# 16680                        5          None      None        No          No
#
#              nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# encounter_id
# 2278392               No             No          No            No        No
# 149190                No             No          No            No        No
# 64410                 No             No          No            No    Steady
# 500364                No             No          No            No        No
# 16680                 No             No          No            No    Steady
#
#              glyburide tolbutamide pioglitazone rosiglitazone acarbose  \
# encounter_id
# 2278392             No          No           No            No       No
# 149190              No          No           No            No       No
# 64410               No          No           No            No       No
# 500364              No          No           No            No       No
# 16680               No          No           No            No       No
#
#              miglitol troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 2278392            No           No         No      No          No      No
# 149190             No           No         No      No          No      Up
# 64410              No           No         No      No          No      No
# 500364             No           No         No      No          No      Up
# 16680              No           No         No      No          No  Steady
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 2278392                       No                  No                       No
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 2278392                           No                     No     No
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
#
#              diabetesMed readmitted
# encounter_id
# 2278392               No         NO
# 149190               Yes         NO
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO

# %%
df = df.dropna()
df
# Out:
#                          race  gender      age  admission_type_id  \
# encounter_id
# 149190              Caucasian  Female  [10-20)                  1
# 64410         AfricanAmerican  Female  [20-30)                  1
# 500364              Caucasian    Male  [30-40)                  1
# 16680               Caucasian    Male  [40-50)                  1
# 35754               Caucasian    Male  [50-60)                  2
# ...                       ...     ...      ...                ...
# 443847548     AfricanAmerican    Male  [70-80)                  1
# 443847782     AfricanAmerican  Female  [80-90)                  1
# 443854148           Caucasian    Male  [70-80)                  1
# 443857166           Caucasian  Female  [80-90)                  2
# 443867222           Caucasian    Male  [70-80)                  1
#
#               discharge_disposition_id  admission_source_id  time_in_hospital  \
# encounter_id
# 149190                               1                    7                 3
# 64410                                1                    7                 2
# 500364                               1                    7                 2
# 16680                                1                    7                 1
# 35754                                1                    2                 3
# ...                                ...                  ...               ...
# 443847548                            3                    7                 3
# 443847782                            4                    5                 5
# 443854148                            1                    7                 1
# 443857166                            3                    7                10
# 443867222                            1                    7                 6
#
#               num_lab_procedures  num_procedures  num_medications  \
# encounter_id
# 149190                        59               0               18
# 64410                         11               5               13
# 500364                        44               1               16
# 16680                         51               0                8
# 35754                         31               6               16
# ...                          ...             ...              ...
# 443847548                     51               0               16
# 443847782                     33               3               18
# 443854148                     53               0                9
# 443857166                     45               2               21
# 443867222                     13               3                3
#
#               number_outpatient  number_emergency  number_inpatient  \
# encounter_id
# 149190                        0                 0                 0
# 64410                         2                 0                 1
# 500364                        0                 0                 0
# 16680                         0                 0                 0
# 35754                         0                 0                 0
# ...                         ...               ...               ...
# 443847548                     0                 0                 0
# 443847782                     0                 0                 1
# 443854148                     1                 0                 0
# 443857166                     0                 0                 1
# 443867222                     0                 0                 0
#
#                                                          diag_1  \
# encounter_id
# 149190               External Causes of Injuries and Poisonings
# 64410         Complications Of Pregnancy, Childbirth, And Th...
# 500364                        Infectious And Parasitic Diseases
# 16680                                                 Neoplasms
# 35754                        Diseases Of The Circulatory System
# ...                                                         ...
# 443847548                                              Diabetes
# 443847782                      Diseases Of The Digestive System
# 443854148                     Infectious And Parasitic Diseases
# 443857166                                  Injury And Poisoning
# 443867222                      Diseases Of The Digestive System
#
#                                                       diag_2  \
# encounter_id
# 149190                                              Diabetes
# 64410             External Causes of Injuries and Poisonings
# 500364                                              Diabetes
# 16680                                              Neoplasms
# 35754                     Diseases Of The Circulatory System
# ...                                                      ...
# 443847548                                   Mental Disorders
# 443847782         External Causes of Injuries and Poisonings
# 443854148               Diseases Of The Genitourinary System
# 443857166     Diseases Of The Blood And Blood-Forming Organs
# 443867222                   Diseases Of The Digestive System
#
#                                                          diag_3  \
# encounter_id
# 149190               External Causes of Injuries and Poisonings
# 64410         Supplementary Classification of Factors Influe...
# 500364                       Diseases Of The Circulatory System
# 16680                External Causes of Injuries and Poisonings
# 35754                External Causes of Injuries and Poisonings
# ...                                                         ...
# 443847548                    Diseases Of The Circulatory System
# 443847782           Symptoms, Signs, And Ill-Defined Conditions
# 443854148                                      Mental Disorders
# 443857166                                  Injury And Poisoning
# 443867222           Symptoms, Signs, And Ill-Defined Conditions
#
#               number_diagnoses max_glu_serum A1Cresult metformin repaglinide  \
# encounter_id
# 149190                       9          None      None        No          No
# 64410                        6          None      None        No          No
# 500364                       7          None      None        No          No
# 16680                        5          None      None        No          No
# 35754                        9          None      None        No          No
# ...                        ...           ...       ...       ...         ...
# 443847548                    9          None        >8    Steady          No
# 443847782                    9          None      None        No          No
# 443854148                   13          None      None    Steady          No
# 443857166                    9          None      None        No          No
# 443867222                    9          None      None        No          No
#
#              nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# encounter_id
# 149190                No             No          No            No        No
# 64410                 No             No          No            No    Steady
# 500364                No             No          No            No        No
# 16680                 No             No          No            No    Steady
# 35754                 No             No          No            No        No
# ...                  ...            ...         ...           ...       ...
# 443847548             No             No          No            No        No
# 443847782             No             No          No            No        No
# 443854148             No             No          No            No        No
# 443857166             No             No          No            No    Steady
# 443867222             No             No          No            No        No
#
#              glyburide tolbutamide pioglitazone rosiglitazone acarbose  \
# encounter_id
# 149190              No          No           No            No       No
# 64410               No          No           No            No       No
# 500364              No          No           No            No       No
# 16680               No          No           No            No       No
# 35754               No          No           No            No       No
# ...                ...         ...          ...           ...      ...
# 443847548           No          No           No            No       No
# 443847782           No          No           No            No       No
# 443854148           No          No           No            No       No
# 443857166           No          No       Steady            No       No
# 443867222           No          No           No            No       No
#
#              miglitol troglitazone tolazamide examide citoglipton insulin  \
# encounter_id
# 149190             No           No         No      No          No      Up
# 64410              No           No         No      No          No      No
# 500364             No           No         No      No          No      Up
# 16680              No           No         No      No          No  Steady
# 35754              No           No         No      No          No  Steady
# ...               ...          ...        ...     ...         ...     ...
# 443847548          No           No         No      No          No    Down
# 443847782          No           No         No      No          No  Steady
# 443854148          No           No         No      No          No    Down
# 443857166          No           No         No      No          No      Up
# 443867222          No           No         No      No          No      No
#
#              glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# encounter_id
# 149190                        No                  No                       No
# 64410                         No                  No                       No
# 500364                        No                  No                       No
# 16680                         No                  No                       No
# 35754                         No                  No                       No
# ...                          ...                 ...                      ...
# 443847548                     No                  No                       No
# 443847782                     No                  No                       No
# 443854148                     No                  No                       No
# 443857166                     No                  No                       No
# 443867222                     No                  No                       No
#
#              metformin-rosiglitazone metformin-pioglitazone change  \
# encounter_id
# 149190                            No                     No     Ch
# 64410                             No                     No     No
# 500364                            No                     No     Ch
# 16680                             No                     No     Ch
# 35754                             No                     No     No
# ...                              ...                    ...    ...
# 443847548                         No                     No     Ch
# 443847782                         No                     No     No
# 443854148                         No                     No     Ch
# 443857166                         No                     No     Ch
# 443867222                         No                     No     No
#
#              diabetesMed readmitted
# encounter_id
# 149190               Yes         NO
# 64410                Yes         NO
# 500364               Yes         NO
# 16680                Yes         NO
# 35754                Yes         NO
# ...                  ...        ...
# 443847548            Yes         NO
# 443847782            Yes         NO
# 443854148            Yes         NO
# 443857166            Yes         NO
# 443867222             No         NO
#
# [95673 rows x 45 columns]

# %%
corr = df.corr(method="pearson")
print(corr)
sns.heatmap(corr)
# Out:
#                           admission_type_id  discharge_disposition_id  \
# admission_type_id                  1.000000                  0.089929
# discharge_disposition_id           0.089929                  1.000000
# admission_source_id                0.106133                  0.007893
# time_in_hospital                  -0.012613                  0.161386
# num_lab_procedures                -0.139159                  0.008855
# num_procedures                     0.132903                  0.011142
# num_medications                    0.082299                  0.104468
# number_outpatient                  0.025685                 -0.010879
# number_emergency                  -0.020117                 -0.025843
# number_inpatient                  -0.036797                  0.014057
# number_diagnoses                  -0.120784                  0.023194
#
#                           admission_source_id  time_in_hospital  \
# admission_type_id                    0.106133         -0.012613
# discharge_disposition_id             0.007893          0.161386
# admission_source_id                  1.000000         -0.008247
# time_in_hospital                    -0.008247          1.000000
# num_lab_procedures                   0.052104          0.320161
# num_procedures                      -0.138118          0.189407
# num_medications                     -0.057334          0.461774
# number_outpatient                    0.025147         -0.011209
# number_emergency                     0.059043         -0.010384
# number_inpatient                     0.036131          0.072973
# number_diagnoses                     0.071319          0.211514
#
#                           num_lab_procedures  num_procedures  num_medications  \
# admission_type_id                  -0.139159        0.132903         0.082299
# discharge_disposition_id            0.008855        0.011142         0.104468
# admission_source_id                 0.052104       -0.138118        -0.057334
# time_in_hospital                    0.320161        0.189407         0.461774
# num_lab_procedures                  1.000000        0.052338         0.264941
# num_procedures                      0.052338        1.000000         0.378960
# num_medications                     0.264941        0.378960         1.000000
# number_outpatient                  -0.008587       -0.026948         0.043492
# number_emergency                   -0.000776       -0.039288         0.012973
# number_inpatient                    0.039914       -0.068376         0.063981
# number_diagnoses                    0.147362        0.055406         0.241369
#
#                           number_outpatient  number_emergency  \
# admission_type_id                  0.025685         -0.020117
# discharge_disposition_id          -0.010879         -0.025843
# admission_source_id                0.025147          0.059043
# time_in_hospital                  -0.011209         -0.010384
# num_lab_procedures                -0.008587         -0.000776
# num_procedures                    -0.026948         -0.039288
# num_medications                    0.043492          0.012973
# number_outpatient                  1.000000          0.091247
# number_emergency                   0.091247          1.000000
# number_inpatient                   0.106657          0.268349
# number_diagnoses                   0.092080          0.055067
#
#                           number_inpatient  number_diagnoses
# admission_type_id                -0.036797         -0.120784
# discharge_disposition_id          0.014057          0.023194
# admission_source_id               0.036131          0.071319
# time_in_hospital                  0.072973          0.211514
# num_lab_procedures                0.039914          0.147362
# num_procedures                   -0.068376          0.055406
# num_medications                   0.063981          0.241369
# number_outpatient                 0.106657          0.092080
# number_emergency                  0.268349          0.055067
# number_inpatient                  1.000000          0.101269
# number_diagnoses                  0.101269          1.000000

# %%
df["readmitted"].describe()
# Out:
# count     95673
# unique        2
# top          NO
# freq      84650
# Name: readmitted, dtype: object

# %%
sns.countplot(df['readmitted'])
plt.show()

# %%
cat_columns = df.select_dtypes(['object']).columns
cat_columns_id = df.columns.get_indexer(cat_columns)
df[cat_columns] = df[cat_columns].astype('category')
df[cat_columns] = df[cat_columns].apply(lambda x : x.cat.codes)

# %%
data = df.to_numpy()
x, y = data[:, :-1], data[:, -1:]

# %%
y
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int64)

# %%
df["readmitted"]
# Out:
# encounter_id
# 149190       0
# 64410        0
# 500364       0
# 16680        0
# 35754        0
#             ..
# 443847548    0
# 443847782    0
# 443854148    0
# 443857166    0
# 443867222    0
# Name: readmitted, Length: 95673, dtype: int8

# %%
smotenc = imblearn.over_sampling.SMOTENC(categorical_features=cat_columns_id[:-1], random_state=0, n_jobs=-1)
x_resampled, y_resampled = smotenc.fit_resample(x, y)

# %%
sns.countplot(y_resampled)
plt.show()

# %%
scaler = preprocessing.StandardScaler()
x_scaled = x_resampled.copy()
x_scaled = scaler.fit_transform(x_scaled)
print(x_scaled)
# Out:
# [[ 3.42382000e-01 -8.91889747e-01 -3.60941006e+00 ... -2.43037228e-03
#   -1.09044199e+00  4.71116076e-01]
#  [-2.37319143e+00 -8.91889747e-01 -2.92387631e+00 ... -2.43037228e-03
#    9.17059330e-01  4.71116076e-01]
#  [ 3.42382000e-01  1.12116114e+00 -2.23834257e+00 ... -2.43037228e-03
#   -1.09044199e+00  4.71116076e-01]
#  ...
#  [-2.37319143e+00  1.12116114e+00 -8.67275093e-01 ... -2.43037228e-03
#   -1.09044199e+00  4.71116076e-01]
#  [ 3.42382000e-01 -8.91889747e-01 -1.81741352e-01 ... -2.43037228e-03
#   -1.09044199e+00  4.71116076e-01]
#  [ 3.42382000e-01 -8.91889747e-01 -1.55280883e+00 ... -2.43037228e-03
#   -1.09044199e+00  4.71116076e-01]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_resampled, test_size=0.2, random_state=0)

# %%
os.makedirs('preprocessed', exist_ok=True)
np.savetxt("preprocessed/x_train.csv", x_train, delimiter=",")
np.savetxt("preprocessed/y_train.csv", y_train, delimiter=",")
np.savetxt("preprocessed/x_test.csv", x_test, delimiter=",")
np.savetxt("preprocessed/y_test.csv", y_test, delimiter=",")

# %%
x_train
# Out:
# array([[2, 1, 5, ..., 0, 1, 0],
#        [2, 0, 6, ..., 0, 1, 0],
#        [2, 0, 7, ..., 0, 1, 1],
#        ...,
#        [0, 0, 5, ..., 0, 1, 0],
#        [3, 0, 4, ..., 0, 1, 0],
#        [2, 1, 6, ..., 0, 0, 1]], dtype=int64)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
scaler = preprocessing.StandardScaler()
x_train_scaled = x_train.copy()
x_train_scaled = scaler.fit_transform(x_train_scaled)
x_test_scaled = x_test.copy()
x_test_scaled = scaler.transform(x_test_scaled)
print(x_train_scaled)
# Out:
# [[ 0.39751762  1.08109585 -0.70610666 ...  0.          0.93066818
#   -1.83449398]
#  [ 0.39751762 -0.9248901  -0.06566118 ...  0.          0.93066818
#   -1.83449398]
#  [ 0.39751762 -0.9248901   0.57478429 ...  0.          0.93066818
#    0.54510945]
#  ...
#  [-1.92006338 -0.9248901  -0.70610666 ...  0.          0.93066818
#   -1.83449398]
#  [ 1.55630811 -0.9248901  -1.34655214 ...  0.          0.93066818
#   -1.83449398]
#  [ 0.39751762  1.08109585 -0.06566118 ...  0.         -1.07449682
#    0.54510945]]

# %%
x_test_scaled
# Out:
# array([[ 0.39751762, -0.9248901 ,  0.57478429, ...,  0.        ,
#         -1.07449682,  0.54510945],
#        [ 0.39751762, -0.9248901 , -0.70610666, ...,  0.        ,
#          0.93066818, -1.83449398],
#        [ 0.39751762, -0.9248901 , -1.34655214, ...,  0.        ,
#         -1.07449682,  0.54510945],
#        ...,
#        [ 0.39751762, -0.9248901 , -0.70610666, ...,  0.        ,
#          0.93066818,  0.54510945],
#        [ 0.39751762,  1.08109585,  0.57478429, ...,  0.        ,
#          0.93066818,  0.54510945],
#        [ 0.39751762, -0.9248901 ,  1.21522977, ...,  0.        ,
#         -1.07449682,  0.54510945]])

# %%
smotenc = imblearn.over_sampling.SMOTENC(categorical_features=cat_columns_id[:-1], random_state=0, n_jobs=-1)
x_train_r2, y_train_r2 = smotenc.fit_resample(x_train_scaled, y_train)

# %%
os.makedirs('preprocessed1_re', exist_ok=True)
np.savetxt("preprocessed1_re/x_train.csv", x_train_r2, delimiter=",")
np.savetxt("preprocessed1_re/y_train.csv", y_train_r2, delimiter=",")
np.savetxt("preprocessed1_re/x_test.csv", x_test_scaled, delimiter=",")
np.savetxt("preprocessed1_re/y_test.csv", y_test, delimiter=",")

# %%
#################################################
#        undersampled x_train,y_train           #
#################################################
from sklearn.datasets import make_classification
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=0)
x_train_undersampled, y_train_undersampled = rus.fit_resample(x_train_scaled, y_train)

# %%
np.savetxt("preprocessed1_re/x_train_undersampled.csv", x_train_undersampled, delimiter=",")
np.savetxt("preprocessed1_re/y_train_undersampled.csv", y_train_undersampled, delimiter=",")
np.savetxt("preprocessed1_re/x_test.csv", x_test_scaled, delimiter=",")
np.savetxt("preprocessed1_re/y_test.csv", y_test, delimiter=",")
